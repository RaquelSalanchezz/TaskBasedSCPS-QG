# %% [markdown]
# Matplotlib installation

# %%
# %pip install matplotlib

# %% [markdown]
# # RQ1a charts: vehicles

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos GRAFICA 1
algoritmo_genetico_coste = [82, 84, 85, 86, 88]
algoritmo_genetico_timespan = [15.5, 16.0, 16.2, 16.4, 16.7]

milp_coste = [81] * 10  # Repetir 10 veces el valor 1450
milp_timespan = [15.47] * 10  # Repetir 10 veces el valor 1450

# Datos GRAFICA 2
algoritmo_genetico_coste2 = [160,170,180,190,168]
algoritmo_genetico_timespan2 = [17.0,17.2,17.4,17.6,17.8]

milp_coste2 = [160] * 10  # Repetir 10 veces el valor 1450
milp_timespan2 = [16.80] * 10  # Repetir 10 veces el valor 1450

# Datos GRAFICA 3
algoritmo_genetico_coste3 = [450,460,436,465,430]
algoritmo_genetico_timespan3 = [18.8,19.0,19.4,19.6,19.8]

milp_coste3 = [426] * 10  # Repetir 10 veces el valor 1450
milp_timespan3 = [18.6] * 10  # Repetir 10 veces el valor 1450

# Datos GRAFICA 3
algoritmo_genetico_coste4 = [850,860,836,830,828]
algoritmo_genetico_timespan4 = [19.3,19.2,19.4,19.6,19.8]

milp_coste4 = [826] * 10  # Repetir 10 veces el valor 1450
milp_timespan4 = [19] * 10  # Repetir 10 veces el valor 1450





# Configuración del gráfico
fig, axs = plt.subplots(1, 4, figsize=(24, 6))
plt.subplots_adjust(wspace=0.5)  # Ajusta el espacio entre las subgráficas

for i, ax in enumerate(axs):

    # Crear un segundo eje y para timespan en el lado derecho
    ax2 = ax.twinx()

    #GRAFICA 1
    if i == 0:
        # Establece límites específicos para el eje y izquierdo en cada gráfica
        ax.set_ylim([75, 90])

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste, milp_coste], positions=[1, 1.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan, milp_timespan], positions=[2.5, 3], labels=[' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#EVs:20 #chargers:2', fontsize=20)

    #GRAFICA 2
    elif i == 1:
        ax.set_ylim([150, 200])  # Ajusta según tus necesidades

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste2, milp_coste2], positions=[1, 1.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan2, milp_timespan2], positions=[2.5, 3], labels=[' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#EVs:40 #chargers:4', fontsize=20)

    #GRAFICA 3
    elif i == 2:
        ax.set_ylim([400,470])  # Ajusta según tus necesidades

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste3, milp_coste3], positions=[1, 1.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan3, milp_timespan3], positions=[2.5, 3], labels=[' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#EVs:80 #chargers:8', fontsize=20)

    #GRAFICA 4
    elif i == 3:
        ax.set_ylim([810,880])  # Ajusta según tus necesidades

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste4, milp_coste4], positions=[1, 1.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan4, milp_timespan4], positions=[2.5, 3], labels=[' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#EVs:160 #chargers:16', fontsize=20)



    ax.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')

    # Colorea los boxplots de coste
    colors_coste = ['lightblue', 'lightblue']
    for box, color in zip(bp1['boxes'], colors_coste):
        box.set(color='blue', facecolor=color)

    # Ajusta el formato de los ticks en el eje izquierdo
    ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}'.format))

    # Oculta las etiquetas en el eje x
    ax.tick_params(axis='x', which='both', bottom=False)

    ax2.text(2.5, 15, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(3, 15, 'MILP', ha='center', va='center', fontsize=12, color='black')

    ax2.text(1, 15, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(1.5, 15, 'MILP', ha='center', va='center', fontsize=12, color='black')

    ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
    ax2.set_ylim([14.5, 20])  # Ajusta el rango según tus datos

    ax2.text(1.25, 14, 'Cost', ha='center', va='center', fontsize=20, color='blue')
    ax2.text(2.75, 14, 'Timespan', ha='center', va='center', fontsize=20, color='red')

    # Colorea los boxplots de timespan
    colors_timespan = ['lightsalmon', 'lightsalmon']
    for box, color in zip(bp2['boxes'], colors_timespan):
        box.set(color='red', facecolor=color)



    # Ajusta el tamaño de las etiquetas de los ejes
    ax.tick_params(axis='both', labelsize=12)
    ax2.tick_params(axis='both', labelsize=12)


plt.savefig('Grafica_RQ1_Vehiculos.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos GRAFICA 1
algoritmo_genetico_coste = [82, 84, 85, 86, 88]
algoritmo_genetico_timespan = [15.5, 16.0, 16.2, 16.4, 16.7]

algoritmo_genetico_coste_md = [85] * 10
algoritmo_genetico_timespan_md = [15.87] * 10

milp_coste = [81] * 10  # Repetir 10 veces el valor 1450
milp_timespan = [15.47] * 10  # Repetir 10 veces el valor 1450

milp_coste_md = [82] * 10  # Repetir 10 veces el valor 1450
milp_timespan_md = [15.67] * 10  # Repetir 10 veces el valor 1450

# Datos GRAFICA 2
algoritmo_genetico_coste2 = [160,170,180,190,168]
algoritmo_genetico_timespan2 = [17.0,17.2,17.4,17.6,17.8]

milp_coste2 = [160] * 10  # Repetir 10 veces el valor 1450
milp_timespan2 = [16.80] * 10  # Repetir 10 veces el valor 1450

algoritmo_genetico_coste_md2 = [163] * 10
algoritmo_genetico_timespan_md2 = [16.98] * 10

milp_coste_md2 = [161] * 10  # Repetir 10 veces el valor 1450
milp_timespan_md2 = [16.9] * 10  # Repetir 10 veces el valor 1450

# Datos GRAFICA 3
algoritmo_genetico_coste3 = [450,460,436,465,430]
algoritmo_genetico_timespan3 = [18.8,19.0,19.4,19.6,19.8]

milp_coste3 = [426] * 10  # Repetir 10 veces el valor 1450
milp_timespan3 = [18.6] * 10  # Repetir 10 veces el valor 1450

algoritmo_genetico_coste_md3 = [438] * 10
algoritmo_genetico_timespan_md3 = [19.2] * 10

milp_coste_md3 = [427] * 10  # Repetir 10 veces el valor 1450
milp_timespan_md3 = [18.8] * 10  # Repetir 10 veces el valor 1450





# Configuración del gráfico
fig, axs = plt.subplots(1, 3, figsize=(24, 6))
plt.subplots_adjust(wspace=0.5)  # Ajusta el espacio entre las subgráficas

for i, ax in enumerate(axs):

    # Crear un segundo eje y para timespan en el lado derecho
    ax2 = ax.twinx()

    #GRAFICA 1
    if i == 0:
        # Establece límites específicos para el eje y izquierdo en cada gráfica
        ax.set_ylim([75, 90])

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste, milp_coste], positions=[1, 1.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan, milp_timespan], positions=[2.5, 3], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp3 = ax.boxplot([algoritmo_genetico_coste_md, milp_coste_md], positions=[4, 4.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp4 = ax2.boxplot([algoritmo_genetico_timespan_md, milp_timespan_md], positions=[5.5, 6], labels=[' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#EVs:20 #chargers:2', fontsize=20)

    #GRAFICA 2
    elif i == 1:
        ax.set_ylim([150, 200])  # Ajusta según tus necesidades

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste2, milp_coste2], positions=[1, 1.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan2, milp_timespan2], positions=[2.5, 3], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp3 = ax.boxplot([algoritmo_genetico_coste_md2, milp_coste_md2], positions=[4, 4.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp4 = ax2.boxplot([algoritmo_genetico_timespan_md2, milp_timespan_md2], positions=[5.5, 6], labels=[' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#EVs:40 #chargers:4', fontsize=20)

    #GRAFICA 3
    elif i == 2:
        ax.set_ylim([400,470])  # Ajusta según tus necesidades

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste3, milp_coste3], positions=[1, 1.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan3, milp_timespan3], positions=[2.5, 3], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp3 = ax.boxplot([algoritmo_genetico_coste_md3, milp_coste_md3], positions=[4, 4.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp4 = ax2.boxplot([algoritmo_genetico_timespan_md3, milp_timespan_md3], positions=[5.5, 6], labels=[' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#EVs:80 #chargers:8', fontsize=20)





    ax.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')

    # Colorea los boxplots de coste
    colors_coste = ['lightblue', 'lightblue']
    for box, color in zip(bp1['boxes'], colors_coste):
        box.set(color='blue', facecolor=color)

    # Ajusta el formato de los ticks en el eje izquierdo
    ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}'.format))

    # Oculta las etiquetas en el eje x
    ax.tick_params(axis='x', which='both', bottom=False)

    ax2.text(2.5, 15, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(3, 15, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(4, 15, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(4.5, 15, 'MILP', ha='center', va='center', fontsize=12, color='black')

    ax2.text(1, 15, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(1.5, 15, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(5.5, 15, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(6, 15, 'MILP', ha='center', va='center', fontsize=12, color='black')

    ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
    ax2.set_ylim([14.5, 20])  # Ajusta el rango según tus datos

    ax2.text(1.15, 14, 'Cost', ha='center', va='center', fontsize=20, color='blue')
    ax2.text(2.55, 14, 'Timespan', ha='center', va='center', fontsize=20, color='red')
    ax2.text(4.25, 14, 'Cost', ha='center', va='center', fontsize=20, color='blue')
    ax2.text(5.75, 14, 'Timespan', ha='center', va='center', fontsize=20, color='red')

    # Colorea los boxplots de timespan
    colors_timespan = ['lightsalmon', 'lightsalmon']
    for box, color in zip(bp2['boxes'], colors_timespan):
        box.set(color='red', facecolor=color)



    # Ajusta el tamaño de las etiquetas de los ejes
    ax.tick_params(axis='both', labelsize=12)
    ax2.tick_params(axis='both', labelsize=12)


plt.savefig('Grafica_RQ1_Vehiculos.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos para gráficos estilo "vehículos" pero del caso de robots

# GRAFICA 1
algoritmo_genetico_coste = [5, 6, 8, 6, 7]
algoritmo_genetico_timespan = [15.5, 16.0, 16.2, 16.4, 16.7]
algoritmo_genetico_coste_md = [6.4] * 10
algoritmo_genetico_timespan_md = [15.96] * 10
milp_coste = [6] * 10
milp_timespan = [15.47] * 10
milp_coste_md = [6] * 10
milp_timespan_md = [15.47] * 10

# GRAFICA 2
algoritmo_genetico_coste2 = [8, 10, 9, 8, 9]
algoritmo_genetico_timespan2 = [17.0, 17.2, 17.4, 17.6, 17.8]
algoritmo_genetico_coste_md2 = [8.8] * 10
algoritmo_genetico_timespan_md2 = [17.4] * 10
milp_coste2 = [8] * 10
milp_timespan2 = [17] * 10
milp_coste_md2 = [8] * 10
milp_timespan_md2 = [17] * 10

# GRAFICA 3
algoritmo_genetico_coste3 = [18, 15, 16, 17, 16]
algoritmo_genetico_timespan3 = [18.8, 19.0, 19.4, 19.6, 19.8]
algoritmo_genetico_coste_md3 = [16.4] * 10
algoritmo_genetico_timespan_md3 = [19.32] * 10
milp_coste3 = [16] * 10
milp_timespan3 = [18.5] * 10
milp_coste_md3 = [16] * 10
milp_timespan_md3 = [18.5] * 10

# Configuración del gráfico
fig, axs = plt.subplots(1, 3, figsize=(24, 6))
plt.subplots_adjust(wspace=0.5)

for i, ax in enumerate(axs):
    ax2 = ax.twinx()

    if i == 0:
        ax.set_ylim([0, 10])
        ax.set_title('#patients:20 #robots:2', fontsize=20)

        bp1 = ax.boxplot([algoritmo_genetico_coste, milp_coste], positions=[1, 1.5], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan, milp_timespan], positions=[2.5, 3], widths=0.4, patch_artist=True)
        bp3 = ax.boxplot([algoritmo_genetico_coste_md, milp_coste_md], positions=[4, 4.5], widths=0.4, patch_artist=True)
        bp4 = ax2.boxplot([algoritmo_genetico_timespan_md, milp_timespan_md], positions=[5.5, 6], widths=0.4, patch_artist=True)

    elif i == 1:
        ax.set_ylim([5, 15])
        ax.set_title('#patients:40 #robots:4', fontsize=20)

        bp1 = ax.boxplot([algoritmo_genetico_coste2, milp_coste2], positions=[1, 1.5], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan2, milp_timespan2], positions=[2.5, 3], widths=0.4, patch_artist=True)
        bp3 = ax.boxplot([algoritmo_genetico_coste_md2, milp_coste_md2], positions=[4, 4.5], widths=0.4, patch_artist=True)
        bp4 = ax2.boxplot([algoritmo_genetico_timespan_md2, milp_timespan_md2], positions=[5.5, 6], widths=0.4, patch_artist=True)

    elif i == 2:
        ax.set_ylim([10, 20])
        ax.set_title('#patients:80 #robots:8', fontsize=20)

        bp1 = ax.boxplot([algoritmo_genetico_coste3, milp_coste3], positions=[1, 1.5], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan3, milp_timespan3], positions=[2.5, 3], widths=0.4, patch_artist=True)
        bp3 = ax.boxplot([algoritmo_genetico_coste_md3, milp_coste_md3], positions=[4, 4.5], widths=0.4, patch_artist=True)
        bp4 = ax2.boxplot([algoritmo_genetico_timespan_md3, milp_timespan_md3], positions=[5.5, 6], widths=0.4, patch_artist=True)

    # Estilo y etiquetas
    ax.set_ylabel('Disruption(#events)', fontsize=20, color='green')
    ax2.set_ylabel('Timespan(h)', fontsize=20, color=(0.91, 0.41, 0.71))
    ax2.set_ylim([14.5, 22])

    ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}'.format))
    ax.tick_params(axis='x', which='both', bottom=False)

    # Etiquetas de categorías
    ax2.text(1, 14, 'GA', ha='center', fontsize=12)
    ax2.text(1.5, 14, 'MILP', ha='center', fontsize=12)
    ax2.text(2.5, 14, 'GA', ha='center', fontsize=12)
    ax2.text(3, 14, 'MILP', ha='center', fontsize=12)
    ax2.text(4, 14, 'GA', ha='center', fontsize=12)
    ax2.text(4.5, 14, 'MILP', ha='center', fontsize=12)
    ax2.text(5.5, 14, 'GA', ha='center', fontsize=12)
    ax2.text(6, 14, 'MILP', ha='center', fontsize=12)

    ax2.text(1.25, 13.5, 'Disruption', ha='center', fontsize=14, color='green')
    ax2.text(2.75, 13.5, 'Timespan', ha='center', fontsize=14, color=(0.91, 0.41, 0.71))
    ax2.text(4.25, 13.5, 'Disruption', ha='center', fontsize=14, color='green')
    ax2.text(5.75, 13.5, 'Timespan', ha='center', fontsize=14, color=(0.91, 0.41, 0.71))

    # Colores
    for box in bp1['boxes'] + bp3['boxes']:
        box.set(color='green', facecolor='lightgreen')
    for box in bp2['boxes'] + bp4['boxes']:
        box.set(color=(0.91, 0.41, 0.71), facecolor='lightpink')

    ax.tick_params(axis='both', labelsize=12)
    ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1_Robots_EstiloVehiculos.pdf', format='pdf')
plt.show()

# %% [markdown]
# # RQ1a charts: robots

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos GRAFICA 1
algoritmo_genetico_coste = [5,6,8,6,7]
algoritmo_genetico_timespan = [15.5, 16.0, 16.2, 16.4, 16.7]

milp_coste = [6] * 10  # Repetir 10 veces el valor 1450
milp_timespan = [15.47] * 10  # Repetir 10 veces el valor 1450

# Datos GRAFICA 2
algoritmo_genetico_coste2 = [8,10,9,8,9]
algoritmo_genetico_timespan2 = [17.0,17.2,17.4,17.6,17.8]

milp_coste2 = [8] * 10  # Repetir 10 veces el valor 1450
milp_timespan2 = [17] * 10  # Repetir 10 veces el valor 1450

# Datos GRAFICA 3
algoritmo_genetico_coste3 = [18,15,16,17,16]
algoritmo_genetico_timespan3 = [18.8,19.0,19.4,19.6,19.8]

milp_coste3 = [16] * 10  # Repetir 10 veces el valor 1450
milp_timespan3 = [18.5] * 10  # Repetir 10 veces el valor 1450

# Datos GRAFICA 3
algoritmo_genetico_coste4 = [31,28,30,33,27]
algoritmo_genetico_timespan4 = [20.3,19.2,21,19.6,19.8]

milp_coste4 = [27] * 10  # Repetir 10 veces el valor 1450
milp_timespan4 = [19.2] * 10  # Repetir 10 veces el valor 1450





# Configuración del gráfico
fig, axs = plt.subplots(1, 4, figsize=(24, 6))
plt.subplots_adjust(wspace=0.5)  # Ajusta el espacio entre las subgráficas

for i, ax in enumerate(axs):

    # Crear un segundo eje y para timespan en el lado derecho
    ax2 = ax.twinx()

    #GRAFICA 1
    if i == 0:
        # Establece límites específicos para el eje y izquierdo en cada gráfica
        ax.set_ylim([0, 10])

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste, milp_coste], positions=[1, 1.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan, milp_timespan], positions=[2.5, 3], labels=[' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#patients:20 #robots:2', fontsize=20)

    #GRAFICA 2
    elif i == 1:
        ax.set_ylim([5, 15])  # Ajusta según tus necesidades

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste2, milp_coste2], positions=[1, 1.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan2, milp_timespan2], positions=[2.5, 3], labels=[' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#patients:40 #robots:4', fontsize=20)

    #GRAFICA 3
    elif i == 2:
        ax.set_ylim([10,20])  # Ajusta según tus necesidades

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste3, milp_coste3], positions=[1, 1.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan3, milp_timespan3], positions=[2.5, 3], labels=[' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#patients:80 #robots:8', fontsize=20)

    #GRAFICA 4
    elif i == 3:
        ax.set_ylim([25,35])  # Ajusta según tus necesidades

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste4, milp_coste4], positions=[1, 1.5], labels=[' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan4, milp_timespan4], positions=[2.5, 3], labels=[' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#patients:160 #robots:16', fontsize=20)



    ax.set_ylabel('Disruption(#events)', fontsize=20, color='green')

    # Colorea los boxplots de coste
    colors_coste = ['lightgreen', 'lightgreen']
    for box, color in zip(bp1['boxes'], colors_coste):
        box.set(color='green', facecolor=color)

    # Ajusta el formato de los ticks en el eje izquierdo
    ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}'.format))

    # Oculta las etiquetas en el eje x
    ax.tick_params(axis='x', which='both', bottom=False)

    ax2.text(2.5, 15, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(3, 15, 'MILP', ha='center', va='center', fontsize=12, color='black')

    ax2.text(1, 15, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(1.5, 15, 'MILP', ha='center', va='center', fontsize=12, color='black')

    ax2.set_ylabel('Timespan(h)', fontsize=20, color=(0.91, 0.41, 0.71))
    ax2.set_ylim([14.5, 22])  # Ajusta el rango según tus datos

    ax2.text(1.25, 14, 'Disruption', ha='center', va='center', fontsize=20, color='green')
    ax2.text(2.75, 14, 'Timespan', ha='center', va='center', fontsize=20, color=(0.91, 0.41, 0.71))

    # Colorea los boxplots de timespan
    colors_timespan = ['lightpink', 'lightpink']
    for box, color in zip(bp2['boxes'], colors_timespan):
        box.set(color=(0.91, 0.41, 0.71), facecolor=color)



    # Ajusta el tamaño de las etiquetas de los ejes
    ax.tick_params(axis='both', labelsize=12)
    ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1_Robots.pdf', format='pdf')
plt.show()

# %% [markdown]
# # RQ1b charts: vehicles

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [77, 79, 80, 81, 83],
    [85, 83, 81, 86, 82],
    [73, 79, 77, 75, 76],
    [75, 73, 79, 76, 74],
    [75, 77, 80, 81, 83]
]

milp_coste_data = [
    [83, 85, 84, 81, 86],
    [91, 89, 88, 93, 90],
    [81, 84, 85, 83, 82],
    [84, 79, 85, 83, 82],
    [81, 85, 84, 83, 82]
]

genetico_timespan_data = [
    [15.75, 16.275, 16.485, 16.695, 17.115],
    [16.8, 15.225, 15.435, 15.645, 16.065],
    [17.325, 15.855, 16.275, 16.8, 16.065],
    [17.85, 17.325, 16.485, 16.695, 16.065],
    [16.8, 15.225, 16.485, 15.645, 16.02]
]

milp_timespan_data = [
    [17.12, 17.675, 17.976, 18.19, 18.832],
    [17.655, 16.364, 17.274, 17.976, 16.996],
    [17.976, 18.404, 17.12, 17.535, 17.244],
    [18.832, 17.99, 18.444, 18.558, 17.976],
    [18.19, 16.585, 17.869, 17.013, 16.996]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([70, 100])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 20])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.5, 11.6, 'Cost', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i+3.5, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:20 #chargers:2', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1b_Vehiculos20.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos para sigma² = 0.25 y sigma² = 0.75
genetico_coste_data = [
    [85, 83, 81, 86, 82],  # σ² = 0.25
    [75, 73, 79, 76, 74]   # σ² = 0.75
]

milp_coste_data = [
    [91, 89, 88, 93, 90],  # σ² = 0.25
    [84, 79, 85, 83, 82]   # σ² = 0.75
]

genetico_coste_data2 = [
    [86] * 5,  # σ² = 0.25
    [75] * 5  # σ² = 0.75
]

milp_coste_data2 = [
    [93] * 5,  # σ² = 0.25
    [83] * 5   # σ² = 0.75
]

genetico_smc_coste_data = [
    [86] * 5,  # σ² = 0.25
    [76] * 5  # σ² = 0.75
]

genetico_timespan_data = [
    [16.8, 15.225, 15.435, 15.645, 16.065],  # σ² = 0.25
    [17.85, 17.325, 16.485, 16.695, 16.065]  # σ² = 0.75
]

milp_timespan_data = [
    [17.655, 16.364, 17.274, 17.976, 16.996],  # σ² = 0.25
    [18.832, 17.99, 18.444, 18.558, 17.976]    # σ² = 0.75
]

genetico_timespan_data2 = [
    [16.065] * 5,  # σ² = 0.25
    [17.325] * 5  # σ² = 0.75
]

milp_timespan_data2 = [
    [17.655] * 5,  # σ² = 0.25
    [18.444] * 5   # σ² = 0.75
]

genetico_smc_timespan_data = [
    [15.645] * 5,  # σ² = 0.25
    [16.485] * 5  # σ² = 0.75
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = [1, 16]
positions_milp_coste = [2, 17]
positions_genetico2_coste = [3, 18]
positions_milp2_coste = [4, 19]
positions_genetico_smc_coste = [5, 20]

positions_genetico_timespan = [7, 22]
positions_milp_timespan = [8, 23]
positions_genetico2_timespan = [9, 24]
positions_milp2_timespan = [10, 25]
positions_genetico_smc_timespan = [11, 26]

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2 = axs.boxplot(genetico_coste_data2, positions=positions_genetico2_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_milp = axs.boxplot(milp_coste_data2, positions=positions_milp2_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bpsmc = axs.boxplot(genetico_smc_coste_data, positions=positions_genetico_smc_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([70, 100])  # Ajusta el rango según tus datos
axs.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# Colorear los boxplots de coste
for box, color in zip(bp1['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bp1_milp['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bp2['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bp2_milp['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bpsmc['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)



# Boxplots para timespan en el eje derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_genetico2 = ax2.boxplot(genetico_timespan_data2, positions=positions_genetico2_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_milp2 = ax2.boxplot(milp_timespan_data2, positions=positions_milp2_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_genetico_smc = ax2.boxplot(genetico_smc_timespan_data, positions=positions_genetico_smc_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 20])  # Ajusta el rango según tus datos

# Colorear los boxplots de timespan
for box, color in zip(bp2_genetico['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_milp['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_genetico2['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_milp2['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_genetico_smc['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

# Etiquetas y anotaciones
for i, sigma_label in zip([3, 18], ['σ² = 0.25', 'σ² = 0.75']):
    ax2.text(i + 2.5, 11, sigma_label, ha='center', va='center', fontsize=16, color='black')

for i in [0,6,15,21]:
    ax2.text(i + 1, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 2, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 3, 12.5, 'GA2', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 4, 12.5, 'MILP2', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 5, 12.5, 'SMC', ha='center', va='center', fontsize=12, color='black')

for i in [0, 15]:
    ax2.text(i + 3, 11.6, 'Cost', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i + 9, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

# Título
plt.suptitle('#EVs:20 #chargers:2', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

# Guardar y mostrar el gráfico
plt.savefig('Grafica_RQ1b_Vehiculos20_sigma_0.25_0.75.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [144.3, 149.1, 152.3, 151.9, 147.7],
    [161.5, 157.7, 153.9, 163.4, 155.8],
    [138.7, 150.1, 146.3, 142.5, 144.4],
    [142.5, 138.7, 150.1, 144.4, 140.6],
    [148.5, 146.3, 151.0, 150.2, 147.7]
]

milp_coste_data = [
    [150.4, 154.0, 152.2, 149.8, 154.8],
    [163.8, 160.2, 158.4, 167.4, 162.0],
    [145.8, 151.2, 153.0, 149.4, 147.6],
    [151.2, 142.2, 153.0, 149.4, 147.6],
    [147.8, 151.0, 152.2, 150.4, 148.6]
]

genetico_timespan_data = [
    [16.0, 16.5, 16.8, 17.0, 17.6],
    [16.5, 15.2, 16.2, 16.8, 15.8],
    [16.8, 17.2, 16.0, 16.5, 16.2],
    [17.6, 17.0, 17.2, 17.4, 16.8],
    [17.0, 15.5, 16.7, 15.9, 15.8]

]

milp_timespan_data = [
    [18.0, 18.6, 18.84, 19.08, 19.56],
    [19.2, 17.4, 17.64, 17.88, 18.36],
    [19.8, 18.12, 18.6, 19.2, 18.36],
    [20.4, 19.8, 18.84, 19.08, 18.36],
    [19.2, 17.4, 18.84, 17.88, 18.24]

]



# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([135, 170])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 25])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.5, 11.6, 'Cost', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i+3.5, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:40 #chargers:', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1b_Vehiculos40.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [304, 308, 310, 312, 316],
    [320, 316, 312, 322, 314],
    [296, 308, 304, 300, 302],
    [300, 296, 308, 302, 298],
    [300, 304, 310, 312, 316]
]

milp_coste_data = [
    [316, 320, 318, 312, 322],
    [332, 328, 326, 336, 330],
    [312, 318, 320, 316, 314],
    [318, 308, 320, 316, 314],
    [312, 320, 318, 316, 314]
]

genetico_timespan_data = [
    [16.5, 17.0, 17.3, 17.5, 18.1],
    [17.0, 15.7, 16.7, 17.3, 16.3],
    [17.3, 17.7, 16.5, 17.0, 16.7],
    [18.1, 17.5, 17.7, 17.9, 17.3],
    [17.5, 16.0, 17.2, 16.4, 16.3]
]

milp_timespan_data = [
    [18.5, 19.1, 19.34, 19.58, 20.06],
    [19.7, 17.9, 18.14, 18.38, 18.86],
    [20.3, 18.62, 19.1, 19.7, 18.86],
    [20.9, 20.3, 19.34, 19.58, 18.86],
    [19.7, 17.9, 19.34, 18.38, 18.74]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([290, 340])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 22])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [300, 310, 320, 330]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.5, 11.6, 'Cost', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i+3.5, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:80 #chargers:8', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_R1b_Vehiculos80.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [640, 632, 624, 644, 628],
    [608, 616, 620, 624, 632],
    [592, 616, 608, 600, 604],
    [600, 592, 608, 604, 596],
    [610, 608, 616, 618, 622]
]

milp_coste_data = [
    [664, 656, 652, 672, 660],
    [632, 640, 636, 624, 644],
    [624, 636, 640, 632, 628],
    [636, 620, 630, 632, 625],
    [624, 640, 636, 632, 628]
]

genetico_timespan_data = [
    [16.5, 17.0, 17.3, 17.5, 18.1],
    [17.0, 15.7, 16.7, 17.3, 16.3],
    [17.3, 17.7, 16.5, 17.0, 16.7],
    [18.0, 17.5, 17.7, 17.9, 17.4],
    [17.2, 16.2, 17, 16.4, 16.5]
]

milp_timespan_data = [
    [18.5, 19.1, 19.34, 19.58, 20.06],
    [19.7, 17.9, 18.14, 18.38, 18.86],
    [20.3, 18.62, 19.1, 19.7, 18.86],
    [20.9, 20.3, 19.34, 19.58, 18.86],
    [19.7, 17.9, 19.34, 18.38, 18.74]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([580, 680])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 22])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [600, 620, 640, 660]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.5, 11.6, 'Cost', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i+3.5, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:160 #chargers:16', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1b_Vehiculos160.pdf', format='pdf')
plt.show()

# %% [markdown]
# Introduciendo probabilidad de fallo de cargadores

# %%
#Probabilidad 0.25

import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [327, 324, 330, 334, 322],
    [344, 349, 357, 347, 354],
    [361, 364, 357, 366, 355],
    [372, 362, 368, 360, 365],
    [372, 379, 374, 368, 377]
]

milp_coste_data = [
    [366, 374, 368, 372, 362],
    [382, 386, 392, 396, 390],
    [398, 408, 405, 413, 402],
    [414, 410, 406, 416, 409],
    [430, 428, 434, 426, 437]
]

genetico_timespan_data = [
    [16.05, 16.2, 15.6, 15.75, 16.4],
    [17.0, 17.5, 16.7, 17.3, 16.9],
    [17.6, 17.4, 16.9, 17.1, 16.72],
    [17.85, 18.5, 18.31, 17.65, 18.1],
    [17.6, 18.05, 17.96, 17.45, 17.2]
]

milp_timespan_data = [
    [18.5, 19.1, 19.34, 18.3, 18.78],
    [20.1, 19.3, 19.2, 19.78, 19.5],
    [20.3, 20.6, 20,7, 20.4, 20.46],
    [21.05, 21.3, 21.44, 21.6, 20.75],
    [21.4, 22.2, 21.74, 21.68, 22.08]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([310, 440])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 24])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [340, 360, 380, 400, 420, 440]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.5, 11.6, 'Cost', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i+3.5, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:80 #chargers:8', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1d_Vehiculos80_p25.pdf', format='pdf')
plt.show()

# %%
#Probabilidad 0.65

import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [395, 396, 401, 402, 403],
    [402, 403, 407, 412, 413],
    [407, 408, 412, 413, 414],
    [412, 413, 418, 419, 420],
    [422, 423, 427, 428, 429]
]

milp_coste_data = [
    [460, 465, 470, 475, 480],
    [472, 474, 480, 483, 479],
    [478, 479, 480, 485, 490],
    [483, 484, 489, 490, 491],
    [498, 499, 504, 509, 510]
]

genetico_timespan_data = [
    [16.8, 17, 17.2, 17.4, 17.6],
    [17.5, 17.8, 18.2, 18.5, 18.8],
    [18.3, 18.6, 18.7, 18.9, 19.2],
    [18.7, 18.9, 19.1, 19.3, 19.5],
    [18.6, 18.8, 19.0, 19.2, 19.4]
]

milp_timespan_data = [
    [20.5, 20.6, 20.8, 21.0, 21.2],
    [21.4, 21.6, 21.8, 22.0, 22.2],
    [22.4, 22.5, 22.6, 22.7, 22.8],
    [22.7, 23.0, 23.3, 23.6, 23.9],
    [23.3, 23.6, 23.8, 24.0, 24.3]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([380, 520])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([14, 26])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [400, 420, 440, 460, 480, 500]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 14.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+2, 14.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+3, 14.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+4, 14.5, 'MILP', ha='center', va='center', fontsize=12, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.5, 13.6, 'Cost', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i+3.5, 13.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 13, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 13, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 13, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 13, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 13, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:80 #chargers:8', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1d_Vehiculos80_p65.pdf', format='pdf')
plt.show()

# %% [markdown]
# # RQ1c charts
#
# Chargers unavailable in some time windows. Vehicles always arrive on schedule.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [296, 308, 304, 300, 302],
    [308, 312, 310, 316, 314],
    [312, 318, 320, 315, 322],
    [322, 325, 327, 326, 324],
    [326, 328, 332, 334, 331]
]

milp_coste_data = [
    [304, 316, 310, 308, 306],
    [312, 318, 314, 322, 316],
    [316, 322, 324, 320, 326],
    [326, 330, 333, 338, 336],
    [330, 332, 334, 338, 337]
]

genetico_timespan_data = [
    [16.5, 17.0, 17.3, 17.5, 18.1],
    [17.0, 15.7, 16.7, 17.3, 16.3],
    [17.3, 17.7, 16.5, 17.0, 16.7],
    [18.1, 17.5, 17.7, 17.9, 17.3],
    [17.5, 16.0, 17.2, 16.4, 16.3]
]

milp_timespan_data = [
    [18.5, 19.1, 19.34, 19.58, 20.06],
    [19.7, 17.9, 18.14, 18.38, 18.86],
    [20.3, 18.62, 19.1, 19.7, 18.86],
    [20.9, 20.3, 19.34, 19.58, 18.86],
    [19.7, 17.9, 19.34, 18.38, 18.74]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([290, 340])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 22])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [300, 310, 320, 330]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.5, 11.6, 'Cost', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i+3.5, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 's.p = 0.05', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 's.p  = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 's.p  = 0.45', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 's.p  = 0.65', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 's.p  = 0.85', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:80 #chargers:8', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_R1c_Vehiculos80.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [576, 586, 582, 578, 580],
    [594, 592, 600, 602, 596],
    [592, 594, 600, 596, 602],
    [600, 605, 610, 607, 603],
    [614, 616, 618, 625, 622]
]

milp_coste_data = [
    [584, 596, 590, 588, 586],
    [600, 604, 605, 610, 607],
    [598, 604, 606, 602, 608],
    [606, 610, 613, 618, 616],
    [622, 625, 627, 631, 629]
]

genetico_timespan_data = [
    [17.2, 17.5, 18.1, 18.4, 19.0],
    [18.0, 17.2, 17.7, 18.3, 17.3],
    [18.3, 19.2, 17.5, 18.0, 17.7],
    [19.1, 18.5, 19.2, 18.9, 18.3],
    [18.0, 17.0, 18.2, 17.4, 17.6]
]

milp_timespan_data = [
    [19.0, 19.4, 19.64, 20.38, 20.56],
    [19.74, 19.5, 19.0, 19.38, 19.96],
    [20.9, 19.62, 20.1, 20.6, 19.86],
    [21.4, 21.2, 20.34, 20.58, 19.86],
    [20.4, 18.9, 20.64, 19.38, 19.74]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([570, 650])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 22])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [580, 590, 600, 610, 620, 630, 640]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)


# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.5, 11.6, 'Cost', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i+3.5, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 's.p = 0.05', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 's.p  = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 's.p  = 0.45', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 's.p  = 0.65', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 's.p  = 0.85', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:160 #chargers:16', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_R1c_Vehiculos160.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [17, 20, 19, 18, 15],
    [19, 21, 17, 16, 17],
    [17, 20, 19, 18, 21],
    [19, 21, 20, 17, 18],
    [19, 20, 19, 18, 21]
]

milp_coste_data = [
    [19, 20, 21, 22, 20],
    [19, 21, 23, 22, 20],
    [19, 20, 21, 22, 20],
    [19, 21, 23, 22, 20],
    [24, 2, 23, 22, 20]
]


genetico_timespan_data = [
    [17.2, 17.775, 18.485, 18.695, 18.115],
    [20.2, 18.725, 19.435, 19.645, 19.065],
    [21.425, 20.355, 20.775, 21.3, 20.565],
    [22.85, 22.525, 21.985, 22.195, 21.565],
    [23.7, 22.325, 23.985, 22.145, 23.1]
]

milp_timespan_data = [
    [18.12, 19.175, 18.976, 19.69, 19.832],
    [22.155, 20.364, 21.274, 22.476, 21.9],
    [22.476, 22.804, 22.12, 22.535, 22.244],
    [23.232, 23.49, 23.944, 24.058, 23.476],
    [25.19, 24.085, 24.869, 24.513, 24.996]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='tab:green')
axs.set_ylim([10, 35])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='green', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='green', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([12, 26])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [15, 20, 25, 30, 35]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.5, 11.6, 'Disruption', ha='center', va='center', fontsize=12, color='green')
    ax2.text(i+3.5, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color=(0.91, 0.41, 0.71))

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 's.p = 0.05', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 's.p  = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 's.p  = 0.45', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 's.p  = 0.65', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 's.p  = 0.85', ha='center', va='center', fontsize=16, color='black')


# Añadir título superior
plt.suptitle('#patients:80 #robots:8', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1c_Robots80.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [35, 38, 37, 36, 33],
    [37, 39, 35, 35, 35],
    [35, 38, 37, 36, 34],
    [37, 39, 38, 37, 36],
    [35, 38, 37, 36, 34]
]

milp_coste_data = [
    [37, 39, 39, 35, 41],
    [36, 38, 41, 39, 40],
    [37, 39, 38, 35, 40],
    [37, 38, 41, 39, 40],
    [37, 38, 41, 39, 42]
]


genetico_timespan_data = [
    [20.2, 20.775, 21.985, 21.695, 21.115],
    [22.7, 21.225, 22.935, 21.645, 22.065],
    [23.425, 24.355, 23.775, 24.5, 23.165],
    [24.35, 25.825, 23.985, 24.495, 25.565],
    [25.8, 23.725, 24.985, 23.945, 25.02]
]

milp_timespan_data = [
    [20.95, 22.175, 21.976, 22.69, 22.832],
    [24.155, 23.364, 24.274, 23.476, 24.996],
    [24.176, 25.304, 24.62, 25.035, 24.744],
    [25.832, 26.49, 25.944, 26.258, 25.476],
    [25.99, 25.085, 25.869, 25.513, 26.696]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='tab:green')
axs.set_ylim([30, 50])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='green', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='green', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([12, 30])  # Ajusta el rango según tus datos

# Ajusta el tamaño de fuente de los números de la escala en el eje y
axs.tick_params(axis='y', labelsize=14)  # Puedes ajustar el tamaño '14' según tus preferencias


# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [32.5, 35, 37.5, 40, 42.5, 45, 47.5]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=14, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=14, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=14, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=14, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.3, 11.6, 'Disruption', ha='center', va='center', fontsize=13, color='green')
    ax2.text(i+3.6, 11.6, 'Timespan', ha='center', va='center', fontsize=13, color=(0.91, 0.41, 0.71))

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 's.p = 0.05', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 's.p  = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 's.p  = 0.45', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 's.p  = 0.65', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 's.p  = 0.85', ha='center', va='center', fontsize=16, color='black')






# Añadir título superior
plt.suptitle('#patients:160 #robots:16', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1c_Robots160.pdf', format='pdf')
plt.show()

# %% [markdown]
# # RQ1b charts: robots

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [2,4,3,2,1],
    [3,4,1,2,2],
    [2,3,5,6,7],
    [5,6,8,6,7],
    [7,6,8,5,7]
]

milp_coste_data = [
    [3, 4, 4, 2, 5],
    [3, 4, 5, 2, 3],
    [2, 4, 8, 6, 7],
    [7, 6, 9, 6, 8],
    [7, 6, 8, 5, 9]
]

'''
genetico_timespan_data = [
    [15.75, 16.275, 16.485, 16.695, 17.115],
    [16.8, 15.225, 15.435, 15.645, 16.065],
    [17.325, 15.855, 16.275, 16.8, 16.065],
    [17.85, 17.325, 16.485, 16.695, 16.065],
    [16.8, 15.225, 16.485, 15.645, 16.02]
]

milp_timespan_data = [
    [17.12, 17.675, 17.976, 18.19, 18.832],
    [17.655, 16.364, 17.274, 17.976, 16.996],
    [17.976, 18.404, 17.12, 17.535, 17.244],
    [18.832, 17.99, 18.444, 18.558, 17.976],
    [18.19, 16.585, 17.869, 17.013, 16.996]
]'''

genetico_timespan_data = [
    [14.75, 15.275, 15.485, 15.695, 16.115],
    [14.8, 13.225, 13.435, 13.645, 14.065],
    [16.325, 14.855, 15.275, 15.8, 15.065],
    [16.85, 16.325, 15.485, 15.695, 15.065],
    [15.8, 13.225, 15.485, 13.645, 15.02]
]

milp_timespan_data = [
    [16.12, 16.675, 16.976, 17.19, 17.832],
    [16.655, 15.364, 16.274, 16.976, 15.996],
    [16.976, 17.404, 16.12, 16.535, 16.244],
    [17.832, 16.99, 17.444, 17.558, 16.976],
    [17.19, 15.585, 16.869, 16.013, 15.996]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='tab:blue')
axs.set_ylim([0, 10])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 20])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.5, 11.6, 'Disruption', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i+3.5, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#patients:20 #robots:2', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1b_Robots20.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [4, 8, 6, 4, 2],
    [6, 5, 3, 7, 4],
    [4, 6, 8, 11, 7],
    [9, 10, 11, 8, 11],
    [12, 13, 14, 11, 14]
]

milp_coste_data = [
    [6, 8, 8, 4, 10],
    [6, 9, 10, 5, 6],
    [6, 8, 10, 12, 14],
    [14, 12, 18, 12, 16],
    [14, 17, 16, 13, 15]
]


'''
genetico_timespan_data = [
    [15.75, 16.275, 16.485, 16.695, 17.115],
    [16.8, 15.225, 15.435, 15.645, 16.065],
    [17.325, 15.855, 16.275, 16.8, 16.065],
    [17.85, 17.325, 16.485, 16.695, 16.065],
    [16.8, 15.225, 16.485, 15.645, 16.02]
]

milp_timespan_data = [
    [17.12, 17.675, 17.976, 18.19, 18.832],
    [17.655, 16.364, 17.274, 17.976, 16.996],
    [17.976, 18.404, 17.12, 17.535, 17.244],
    [18.832, 17.99, 18.444, 18.558, 17.976],
    [18.19, 16.585, 17.869, 17.013, 16.996]
]'''

genetico_timespan_data = [
    [15.25, 15.775, 16.985, 16.195, 16.615],
    [15.3, 13.725, 13.935, 14.145, 14.565],
    [16.825, 15.355, 15.775, 16.3, 15.565],
    [17.35, 16.825, 15.985, 16.195, 15.565],
    [16.3, 13.725, 15.985, 14.145, 16.52]
]

milp_timespan_data = [
    [16.62, 17.175, 17.476, 17.69, 18.332],
    [17.155, 15.864, 16.774, 17.476, 16.496],
    [16.476, 17.304, 16.62, 17.035, 16.744],
    [18.332, 17.49, 17.944, 18.058, 17.476],
    [17.69, 16.085, 17.369, 16.513, 16.496]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='tab:blue')
axs.set_ylim([0, 20])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 20])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.5, 11.6, 'Disruptions', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i+3.5, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#patients:40 #robots:4', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1b_Robots40.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [17, 20, 19, 18, 15],
    [19, 21, 17, 17, 17],
    [20, 19, 23, 25, 23],
    [23, 24, 29, 25, 27],
    [27, 25, 26, 23, 24]
]

milp_coste_data = [
    [19, 21, 21, 17, 23],
    [19, 20, 23, 21, 22],
    [19, 21, 26, 25, 27],
    [27, 25, 30, 25, 29],
    [26, 25, 31, 23, 33]
]


genetico_timespan_data = [
    [17.75, 18.775, 19.485, 19.695, 19.115],
    [18.2, 16.725, 17.435, 17.645, 17.065],
    [19.425, 18.355, 18.775, 19.3, 18.565],
    [19.85, 19.825, 18.985, 19.195, 18.565],
    [19.8, 16.725, 18.985, 17.145, 19.02]
]

milp_timespan_data = [
    [19.12, 20.175, 19.976, 20.69, 20.832],
    [20.155, 18.364, 19.274, 20.476, 19.996],
    [19.976, 20.304, 19.62, 20.035, 19.744],
    [20.832, 20.49, 20.944, 21.058, 20.476],
    [20.19, 19.085, 19.869, 19.513, 19.996]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='tab:green')
axs.set_ylim([10, 35])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='green', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='green', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([12, 22])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [15, 20, 25, 30]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=12, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.5, 11.6, 'Disruption', ha='center', va='center', fontsize=12, color='green')
    ax2.text(i+3.5, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color=(0.91, 0.41, 0.71))

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#patients:80 #robots:8', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1b_Robots80.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [35, 38, 37, 36, 33],
    [37, 39, 35, 35, 35],
    [38, 37, 41, 43, 41],
    [41, 42, 47, 43, 45],
    [45, 43, 44, 41, 42]
]

milp_coste_data = [
    [37, 39, 39, 35, 41],
    [37, 38, 41, 39, 40],
    [37, 39, 44, 43, 45],
    [45, 43, 48, 43, 47],
    [44, 43, 49, 41, 49]
]


genetico_timespan_data = [
    [20.2, 20.775, 21.985, 21.695, 21.115],
    [19.7, 18.225, 19.935, 18.645, 19.065],
    [20.425, 21.355, 20.775, 21.5, 20.165],
    [21.35, 22.825, 20.985, 21.495, 22.565],
    [21.8, 19.725, 20.985, 19.945, 21.02]
]

milp_timespan_data = [
    [20.95, 22.175, 21.976, 22.69, 22.832],
    [21.155, 20.364, 21.274, 20.476, 21.996],
    [21.176, 22.304, 21.62, 22.035, 21.744],
    [22.832, 23.49, 22.944, 23.258, 22.476],
    [21.99, 21.085, 21.869, 21.513, 22.696]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='tab:green')
axs.set_ylim([30, 50])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='green', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([12, 25])  # Ajusta el rango según tus datos

# Ajusta el tamaño de fuente de los números de la escala en el eje y
axs.tick_params(axis='y', labelsize=14)  # Puedes ajustar el tamaño '14' según tus preferencias


# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [32.5, 35, 37.5, 40, 42.5, 45, 47.5]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=14, color='black')
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=14, color='black')
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=14, color='black')
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=14, color='black')

for i in range(0, 30, 6):
    ax2.text(i+1.3, 11.6, 'Disruption', ha='center', va='center', fontsize=13, color='green')
    ax2.text(i+3.6, 11.6, 'Timespan', ha='center', va='center', fontsize=13, color=(0.91, 0.41, 0.71))

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')





# Añadir título superior
plt.suptitle('#patients:160 #robots:16', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1b_Robots160.pdf', format='pdf')
plt.show()

# %% [markdown]
# # Graphs with modified size

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [17, 20, 19, 18, 15],
    [19, 21, 17, 17, 17],
    [20, 19, 23, 25, 23],
    [23, 24, 29, 25, 27],
    [27, 25, 26, 23, 24]
]

milp_coste_data = [
    [19, 21, 21, 17, 23],
    [19, 20, 23, 21, 22],
    [19, 21, 26, 25, 27],
    [27, 25, 30, 25, 29],
    [26, 25, 31, 23, 33]
]

genetico_timespan_data = [
    [17.75, 18.775, 19.485, 19.695, 19.115],
    [18.2, 16.725, 17.435, 17.645, 17.065],
    [19.425, 18.355, 18.775, 19.3, 18.565],
    [19.85, 19.825, 18.985, 19.195, 18.565],
    [19.8, 16.725, 18.985, 17.145, 19.02]
]

milp_timespan_data = [
    [19.12, 20.175, 19.976, 20.69, 20.832],
    [20.155, 18.364, 19.274, 20.476, 19.996],
    [19.976, 20.304, 19.62, 20.035, 19.744],
    [20.832, 20.49, 20.944, 21.058, 20.476],
    [20.19, 19.085, 19.869, 19.513, 19.996]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(10, 8))  # Ajustar ancho del gráfico

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='tab:green')
axs.set_ylim([12, 35])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='green', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='green', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([13, 22])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [15, 20, 25, 30]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

# Etiquetas para GA y MILP ------ MODIFICACION
for i in range(0, 30, 6):
    ax2.text(i+1, 13.5, 'GA', ha='center', va='center', fontsize=14, color='black', rotation=90)  # Rotar texto
    ax2.text(i+2, 13.5, 'MILP', ha='center', va='center', fontsize=14, color='black', rotation=90)  # Rotar texto
    ax2.text(i+3, 13.5, 'GA', ha='center', va='center', fontsize=14, color='black', rotation=90)  # Rotar texto
    ax2.text(i+4, 13.5, 'MILP', ha='center', va='center', fontsize=14, color='black', rotation=90)  # Rotar texto

'''for i in range(0, 30, 6):
    ax2.text(i+1.5, 9.6, 'Disruption', ha='center', va='center', fontsize=12, color='green', rotation=90)  # Rotar texto
    ax2.text(i+3.5, 9.6, 'Timespan', ha='center', va='center', fontsize=12, color=(0.91, 0.41, 0.71), rotation=90)  # Rotar texto'''

for i in range(0, 30, 6):
    if i==0:
        ax2.text(i+2.5, 12.5, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
        ax2.text(i+2.5, 12.5, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
        ax2.text(i+2.5, 12.5, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
        ax2.text(i+2.5, 12.5, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
        ax2.text(i+2.5, 12.5, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#patients:80 #robots:8', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1b_Robots80.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [35, 38, 37, 36, 33],
    [37, 39, 35, 35, 35],
    [38, 37, 41, 43, 41],
    [41, 42, 47, 43, 45],
    [45, 43, 44, 41, 42]
]

milp_coste_data = [
    [37, 39, 39, 35, 41],
    [37, 38, 41, 39, 40],
    [37, 39, 44, 43, 45],
    [45, 43, 48, 43, 47],
    [44, 43, 49, 41, 49]
]


genetico_timespan_data = [
    [20.2, 20.775, 21.985, 21.695, 21.115],
    [19.7, 18.225, 19.935, 18.645, 19.065],
    [20.425, 21.355, 20.775, 21.5, 20.165],
    [21.35, 22.825, 20.985, 21.495, 22.565],
    [21.8, 19.725, 20.985, 19.945, 21.02]
]

milp_timespan_data = [
    [20.95, 22.175, 21.976, 22.69, 22.832],
    [21.155, 20.364, 21.274, 20.476, 21.996],
    [21.176, 22.304, 21.62, 22.035, 21.744],
    [22.832, 23.49, 22.944, 23.258, 22.476],
    [21.99, 21.085, 21.869, 21.513, 22.696]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(10, 8))  # Ajustar ancho del gráfico

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='tab:green')
axs.set_ylim([30, 50])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='green', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='green', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([12, 25])  # Ajusta el rango según tus datos

# Ajusta el tamaño de fuente de los números de la escala en el eje y
axs.tick_params(axis='y', labelsize=14)  # Puedes ajustar el tamaño '14' según tus preferencias


# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [32.5, 35, 37.5, 40, 42.5, 45, 47.5]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

# Etiquetas para GA y MILP ------ MODIFICACION
for i in range(0, 30, 6):
    ax2.text(i+1, 12.7, 'GA', ha='center', va='center', fontsize=14, color='black', rotation=90)  # Rotar texto
    ax2.text(i+2, 12.7, 'MILP', ha='center', va='center', fontsize=14, color='black', rotation=90)  # Rotar texto
    ax2.text(i+3, 12.7, 'GA', ha='center', va='center', fontsize=14, color='black', rotation=90)  # Rotar texto
    ax2.text(i+4, 12.7, 'MILP', ha='center', va='center', fontsize=14, color='black', rotation=90)  # Rotar texto



for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11.5, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11.5, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11.5, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11.5, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11.5, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')





# Añadir título superior
plt.suptitle('#patients:160 #robots:16', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1b_Robots160.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [296, 308, 304, 300, 302],
    [308, 312, 310, 316, 314],
    [312, 318, 320, 315, 322],
    [322, 325, 327, 326, 324],
    [326, 328, 332, 334, 331]
]

milp_coste_data = [
    [304, 316, 310, 308, 306],
    [312, 318, 314, 322, 316],
    [316, 322, 324, 320, 326],
    [326, 330, 333, 338, 336],
    [330, 332, 334, 338, 337]
]

genetico_timespan_data = [
    [16.5, 17.0, 17.3, 17.5, 18.1],
    [17.0, 15.7, 16.7, 17.3, 16.3],
    [17.3, 17.7, 16.5, 17.0, 16.7],
    [18.1, 17.5, 17.7, 17.9, 17.3],
    [17.5, 16.0, 17.2, 16.4, 16.3]
]

milp_timespan_data = [
    [18.5, 19.1, 19.34, 19.58, 20.06],
    [19.7, 17.9, 18.14, 18.38, 18.86],
    [20.3, 18.62, 19.1, 19.7, 18.86],
    [20.9, 20.3, 19.34, 19.58, 18.86],
    [19.7, 17.9, 19.34, 18.38, 18.74]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(10, 8))  # Ajustar ancho del gráfico

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([290, 340])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 22])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [300, 310, 320, 330]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

# Etiquetas para GA y MILP ------ MODIFICACION
for i in range(0, 30, 6):
    ax2.text(i+1, 12.7, 'GA', ha='center', va='center', fontsize=14, color='black', rotation=90)  # Rotar texto
    ax2.text(i+2, 12.7, 'MILP', ha='center', va='center', fontsize=14, color='black', rotation=90)  # Rotar texto
    ax2.text(i+3, 12.7, 'GA', ha='center', va='center', fontsize=14, color='black', rotation=90)  # Rotar texto
    ax2.text(i+4, 12.7, 'MILP', ha='center', va='center', fontsize=14, color='black', rotation=90)  # Rotar texto


for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11.5, 's.p = 0.05', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11.5, 's.p  = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11.5, 's.p  = 0.45', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11.5, 's.p  = 0.65', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11.5, 's.p  = 0.85', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:80 #chargers:8', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_R1c_Vehiculos80.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [576, 586, 582, 578, 580],
    [594, 592, 600, 602, 596],
    [592, 594, 600, 596, 602],
    [600, 605, 610, 607, 603],
    [614, 616, 618, 625, 622]
]

milp_coste_data = [
    [584, 596, 590, 588, 586],
    [600, 604, 605, 610, 607],
    [598, 604, 606, 602, 608],
    [606, 610, 613, 618, 616],
    [622, 625, 627, 631, 629]
]

genetico_timespan_data = [
    [17.2, 17.5, 18.1, 18.4, 19.0],
    [18.0, 17.2, 17.7, 18.3, 17.3],
    [18.3, 19.2, 17.5, 18.0, 17.7],
    [19.1, 18.5, 19.2, 18.9, 18.3],
    [18.0, 17.0, 18.2, 17.4, 17.6]
]

milp_timespan_data = [
    [19.0, 19.4, 19.64, 20.38, 20.56],
    [19.74, 19.5, 19.0, 19.38, 19.96],
    [20.9, 19.62, 20.1, 20.6, 19.86],
    [21.4, 21.2, 20.34, 20.58, 19.86],
    [20.4, 18.9, 20.64, 19.38, 19.74]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(10, 8))  # Ajustar ancho del gráfico

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([570, 650])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 22])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [580, 590, 600, 610, 620, 630, 640]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)


# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=14, color='black',  rotation=90) # Rotar texto
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=14, color='black',  rotation=90) # Rotar texto
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=14, color='black',  rotation=90) # Rotar texto
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=14, color='black',  rotation=90) # Rotar texto

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11.5, 's.p = 0.05', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11.5, 's.p  = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11.5, 's.p  = 0.45', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11.5, 's.p  = 0.65', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11.5, 's.p  = 0.85', ha='center', va='center', fontsize=16, color='black')


# Añadir título superior
plt.suptitle('#EVs:160 #chargers:16', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_R1c_Vehiculos160.pdf', format='pdf')
plt.show()

# %% [markdown]
# #RQ1d charts

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [17, 20, 19, 18, 15],
    [19, 21, 17, 16, 17],
    [17, 20, 19, 18, 21],
    [19, 21, 20, 17, 18],
    [19, 20, 19, 18, 21]
]

milp_coste_data = [
    [19, 20, 21, 22, 20],
    [19, 21, 23, 22, 20],
    [19, 20, 21, 22, 20],
    [19, 21, 23, 22, 20],
    [24, 2, 23, 22, 20]
]


genetico_timespan_data = [
    [17.2, 17.775, 18.485, 18.695, 18.115],
    [20.2, 18.725, 19.435, 19.645, 19.065],
    [21.425, 20.355, 20.775, 21.3, 20.565],
    [22.85, 22.525, 21.985, 22.195, 21.565],
    [23.7, 22.325, 23.985, 22.145, 23.1]
]

milp_timespan_data = [
    [18.12, 19.175, 18.976, 19.69, 19.832],
    [22.155, 20.364, 21.274, 22.476, 21.9],
    [22.476, 22.804, 22.12, 22.535, 22.244],
    [23.232, 23.49, 23.944, 24.058, 23.476],
    [25.19, 24.085, 24.869, 24.513, 24.996]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(10, 8))  # Ajustar ancho del gráfico

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='tab:green')
axs.set_ylim([10, 35])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='green', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='green', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([12, 26])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [15, 20, 25, 30, 35]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.7, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+2, 12.7, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+3, 12.7, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+4, 12.7, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)



for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11.3, 's.p = 0.05', ha='center', va='center', fontsize=18, color='black')
    elif i==6:
      ax2.text(i+2.5, 11.3, 's.p  = 0.25', ha='center', va='center', fontsize=18, color='black')
    elif i==12:
      ax2.text(i+2.5, 11.3, 's.p  = 0.45', ha='center', va='center', fontsize=18, color='black')
    elif i==18:
      ax2.text(i+2.5, 11.3, 's.p  = 0.65', ha='center', va='center', fontsize=18, color='black')
    elif i==24:
      ax2.text(i+2.5, 11.3, 's.p  = 0.85', ha='center', va='center', fontsize=18, color='black')


# Añadir título superior
plt.suptitle('#patients:80 #robots:8', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1c_Robots80.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [35, 38, 37, 36, 33],
    [37, 39, 35, 35, 35],
    [35, 38, 37, 36, 34],
    [37, 39, 38, 37, 36],
    [35, 38, 37, 36, 34]
]

milp_coste_data = [
    [37, 39, 39, 35, 41],
    [36, 38, 41, 39, 40],
    [37, 39, 38, 35, 40],
    [37, 38, 41, 39, 40],
    [37, 38, 41, 39, 42]
]


genetico_timespan_data = [
    [20.2, 20.775, 21.985, 21.695, 21.115],
    [22.7, 21.225, 22.935, 21.645, 22.065],
    [23.425, 24.355, 23.775, 24.5, 23.165],
    [24.35, 25.825, 23.985, 24.495, 25.565],
    [25.8, 23.725, 24.985, 23.945, 25.02]
]

milp_timespan_data = [
    [20.95, 22.175, 21.976, 22.69, 22.832],
    [24.155, 23.364, 24.274, 23.476, 24.996],
    [24.176, 25.304, 24.62, 25.035, 24.744],
    [25.832, 26.49, 25.944, 26.258, 25.476],
    [25.99, 25.085, 25.869, 25.513, 26.696]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(10, 8))  # Ajustar ancho del gráfico

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='tab:green')
axs.set_ylim([30, 50])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='green', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='green', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([12, 30])  # Ajusta el rango según tus datos

# Ajusta el tamaño de fuente de los números de la escala en el eje y
axs.tick_params(axis='y', labelsize=14)  # Puedes ajustar el tamaño '14' según tus preferencias


# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [32.5, 35, 37.5, 40, 42.5, 45, 47.5]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 13, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+2, 13, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+3, 13, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+4, 13, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)


for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11.2, 's.p = 0.05', ha='center', va='center', fontsize=18, color='black')
    elif i==6:
      ax2.text(i+2.5, 11.2, 's.p  = 0.25', ha='center', va='center', fontsize=18, color='black')
    elif i==12:
      ax2.text(i+2.5, 11.2, 's.p  = 0.45', ha='center', va='center', fontsize=18, color='black')
    elif i==18:
      ax2.text(i+2.5, 11.2, 's.p  = 0.65', ha='center', va='center', fontsize=18, color='black')
    elif i==24:
      ax2.text(i+2.5, 11.2, 's.p  = 0.85', ha='center', va='center', fontsize=18, color='black')



# Añadir título superior
plt.suptitle('#patients:160 #robots:16', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1c_Robots160.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [304, 308, 310, 312, 316],
    [320, 316, 312, 322, 314],
    [296, 308, 304, 300, 302],
    [300, 296, 308, 302, 298],
    [300, 304, 310, 312, 316]
]

milp_coste_data = [
    [316, 320, 318, 312, 322],
    [332, 328, 326, 336, 330],
    [312, 318, 320, 316, 314],
    [318, 308, 320, 316, 314],
    [312, 320, 318, 316, 314]
]

genetico_timespan_data = [
    [16.5, 17.0, 17.3, 17.5, 18.1],
    [17.0, 15.7, 16.7, 17.3, 16.3],
    [17.3, 17.7, 16.5, 17.0, 16.7],
    [18.1, 17.5, 17.7, 17.9, 17.3],
    [17.5, 16.0, 17.2, 16.4, 16.3]
]

milp_timespan_data = [
    [18.5, 19.1, 19.34, 19.58, 20.06],
    [19.7, 17.9, 18.14, 18.38, 18.86],
    [20.3, 18.62, 19.1, 19.7, 18.86],
    [20.9, 20.3, 19.34, 19.58, 18.86],
    [19.7, 17.9, 19.34, 18.38, 18.74]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(10, 8))  # Ajustar ancho del gráfico

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([290, 340])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 22])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [300, 310, 320, 330]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=14, color='black', rotation=90)
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=14, color='black', rotation=90)
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=14, color='black', rotation=90)
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=14, color='black', rotation=90)


for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11.6, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11.6, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11.6, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11.6, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11.6, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:80 #chargers:8', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1b_Vehiculos80.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [640, 632, 624, 644, 628],
    [608, 616, 620, 624, 632],
    [592, 616, 608, 600, 604],
    [600, 592, 608, 604, 596],
    [610, 608, 616, 618, 622]
]

milp_coste_data = [
    [664, 656, 652, 672, 660],
    [632, 640, 636, 624, 644],
    [624, 636, 640, 632, 628],
    [636, 620, 630, 632, 625],
    [624, 640, 636, 632, 628]
]

genetico_timespan_data = [
    [16.5, 17.0, 17.3, 17.5, 18.1],
    [17.0, 15.7, 16.7, 17.3, 16.3],
    [17.3, 17.7, 16.5, 17.0, 16.7],
    [18.0, 17.5, 17.7, 17.9, 17.4],
    [17.2, 16.2, 17, 16.4, 16.5]
]

milp_timespan_data = [
    [18.5, 19.1, 19.34, 19.58, 20.06],
    [19.7, 17.9, 18.14, 18.38, 18.86],
    [20.3, 18.62, 19.1, 19.7, 18.86],
    [20.9, 20.3, 19.34, 19.58, 18.86],
    [19.7, 17.9, 19.34, 18.38, 18.74]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(10, 8))  # Ajustar ancho del gráfico

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([580, 680])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 22])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [600, 620, 640, 660]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.5, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+2, 12.5, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+3, 12.5, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+4, 12.5, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)


for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11.6, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11.6, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11.6, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11.6, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11.6, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:160 #chargers:16', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1b_Vehiculos160.pdf', format='pdf')
plt.show()

# %%
#Probabilidad 0.25

import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [327, 324, 330, 334, 322],
    [344, 349, 357, 347, 354],
    [361, 364, 357, 366, 355],
    [372, 362, 368, 360, 365],
    [372, 379, 374, 368, 377]
]

milp_coste_data = [
    [366, 374, 368, 372, 362],
    [382, 386, 392, 396, 390],
    [398, 408, 405, 413, 402],
    [414, 410, 406, 416, 409],
    [430, 428, 434, 426, 437]
]

genetico_timespan_data = [
    [16.05, 16.2, 15.6, 15.75, 16.4],
    [17.0, 17.5, 16.7, 17.3, 16.9],
    [17.6, 17.4, 16.9, 17.1, 16.72],
    [17.85, 18.5, 18.31, 17.65, 18.1],
    [17.6, 18.05, 17.96, 17.45, 17.2]
]

milp_timespan_data = [
    [18.5, 19.1, 19.34, 18.3, 18.78],
    [20.1, 19.3, 19.2, 19.78, 19.5],
    [20.3, 20.6, 20,7, 20.4, 20.46],
    [21.05, 21.3, 21.44, 21.6, 20.75],
    [21.4, 22.2, 21.74, 21.68, 22.08]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(10, 8))  # Ajustar ancho del gráfico

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([310, 440])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 24])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [340, 360, 380, 400, 420, 440]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 12.7, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+2, 12.7, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+3, 12.7, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+4, 12.7, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)


for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 11.5, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 11.5, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 11.5, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 11.5, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 11.5, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:80 #chargers:8 sp = 0.25', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1d_Vehiculos80_p25.pdf', format='pdf')
plt.show()

# %%
#Probabilidad 0.65

import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [395, 396, 401, 402, 403],
    [402, 403, 407, 412, 413],
    [407, 408, 412, 413, 414],
    [412, 413, 418, 419, 420],
    [422, 423, 427, 428, 429]
]

milp_coste_data = [
    [460, 465, 470, 475, 480],
    [472, 474, 480, 483, 479],
    [478, 479, 480, 485, 490],
    [483, 484, 489, 490, 491],
    [498, 499, 504, 509, 510]
]

genetico_timespan_data = [
    [16.8, 17, 17.2, 17.4, 17.6],
    [17.5, 17.8, 18.2, 18.5, 18.8],
    [18.3, 18.6, 18.7, 18.9, 19.2],
    [18.7, 18.9, 19.1, 19.3, 19.5],
    [18.6, 18.8, 19.0, 19.2, 19.4]
]

milp_timespan_data = [
    [20.5, 20.6, 20.8, 21.0, 21.2],
    [21.4, 21.6, 21.8, 22.0, 22.2],
    [22.4, 22.5, 22.6, 22.7, 22.8],
    [22.7, 23.0, 23.3, 23.6, 23.9],
    [23.3, 23.6, 23.8, 24.0, 24.3]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(10, 8))  # Ajustar ancho del gráfico

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([380, 520])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='blue', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightblue'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='blue', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([14, 26])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color='red', facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightsalmon'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [400, 420, 440, 460, 480, 500]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 14.7, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+2, 14.7, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+3, 14.7, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+4, 14.7, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)

for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 13.6, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 13.6, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 13.6, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 13.6, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 13.6, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#EVs:80 #chargers:8 sp = 0.65' , fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1d_Vehiculos80_p65.pdf', format='pdf')
plt.show()

# %%
#Probabilidad 0.25

import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [17, 16.3, 16.9, 16,8, 17.3],
    [17, 17.5, 17.3, 17.7, 16.7],
    [18.1, 17.2, 17.5, 17.75, 17.8],
    [18.5, 17.5, 18, 18.2, 17.9],
    [18, 17.7, 18.5, 18.3, 17.9]
]

milp_coste_data = [
    [17, 1, 17.3, 16.8, 17.3],
    [18, 17.5, 18.5, 17.8, 18.4],
    [18.1, 19, 17.9, 18.7, 18.4],
    [18.5, 19, 19.4, 18.7, 18.9],
    [18.8, 19.7, 19, 19.5, 19.2]
]

genetico_timespan_data = [
    [18.40, 18.50, 18.67, 18.84, 18.95],
    [18.90, 19.10, 19.24, 19.38, 19.58],
    [19.00, 19.20, 19.36, 19.52, 19.68],
    [19.50, 19.70, 19.85, 20.00, 20.20],
    [19.80, 20.00, 20.07, 20.15, 20.30]
]

milp_timespan_data = [
    [21.00, 21.10, 21.26, 21.42, 21.68],
    [21.20, 21.40, 21.53, 21.66, 21.86],
    [21.40, 21.55, 21.72, 21.89, 22.02],
    [22.10, 22.25, 22.37, 22.49, 22.62],
    [22.20, 22.40, 22.52, 22.64, 22.84]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(10, 8))  # Ajustar ancho del gráfico

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('#Disruption', fontsize=20, color='tab:green')
axs.set_ylim([15,24])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='green', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='green', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([15, 25])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [16,18,20,22]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 15.6, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+2, 15.6, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+3, 15.6, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+4, 15.6, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)


for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 14.5, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 14.5, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 14.5, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 14.5, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 14.5, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#patients:80 #robots:8  sp = 0.25', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1d_Robots80_p25.pdf', format='pdf')
plt.show()

# %%
#Probabilidad 0.65

import matplotlib.pyplot as plt
import numpy as np

# Datos de ejemplo
num_datasets = 5  # Número de conjuntos de datos
genetico_coste_data = [
    [17.30, 17.50, 17.64, 17.78, 18.00],
    [17.80, 18.00, 18.14, 18.28, 18.50],
    [18.10, 18.30, 18.46, 18.62, 18.82],
    [18.20, 18.40, 18.58, 18.76, 18.96],
    [18.40, 18.60, 18.75, 18.90, 19.10]
]

milp_coste_data = [
    [18.00, 18.20, 18.37, 18.54, 18.72],
    [18.50, 18.70, 18.92, 19.10, 19.38],
    [19.10, 19.30, 19.45, 19.60, 19.80],
    [19.30, 19.50, 19.62, 19.74, 19.94],
    [19.50, 19.65, 19.81, 19.95, 20.10]
]

genetico_timespan_data = [
    [20.30, 20.45, 20.58, 20.70, 20.85],
    [20.40, 20.50, 20.63, 20.75, 20.85],
    [20.45, 20.55, 20.64, 20.75, 20.85],
    [20.30, 20.40, 20.47, 20.55, 20.70],
    [20.90, 21.05, 21.15, 21.25, 21.40]
]

milp_timespan_data = [
    [23.50, 23.70, 23.81, 23.90, 24.10],
    [23.60, 23.70, 23.82, 23.95, 24.05],
    [23.70, 23.85, 23.92, 24.05, 24.20],
    [24.00, 24.10, 24.26, 24.40, 24.50],
    [24.50, 24.65, 24.82, 24.95, 25.10]
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(10, 8))  # Ajustar ancho del gráfico

# Crear un segundo eje y para timespan en el lado derecho
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = np.arange(1, 3 * num_datasets * 2, step=6)
positions_milp_coste = np.arange(2, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

axs.set_ylabel('#Disruption', fontsize=20, color='tab:green')
axs.set_ylim([16,24])  # Ajusta el rango según tus datos

# Colorea los boxplots de coste para genetico
colors_genetico_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1['boxes'], colors_genetico_coste):
    box.set(color='green', facecolor=color)

# Colorea los boxplots de coste para milp
colors_milp_coste = ['lightgreen'] * num_datasets
for box, color in zip(bp1_milp['boxes'], colors_milp_coste):
    box.set(color='green', facecolor=color)

# Posiciones para los boxplots de timespan
positions_genetico_timespan = np.arange(3, 3 * num_datasets * 2, step=6)
positions_milp_timespan = np.arange(4, 3 * num_datasets * 2 + 1, step=6)

# Boxplots para timespan en el lado derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[f' ' for i in range(num_datasets)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([15, 26])  # Ajusta el rango según tus datos

# Colorea los boxplots de timespan para genetico
colors_genetico_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_genetico['boxes'], colors_genetico_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Colorea los boxplots de timespan para milp
colors_milp_timespan = ['lightpink'] * num_datasets
for box, color in zip(bp2_milp['boxes'], colors_milp_timespan):
    box.set(color=(0.91, 0.41, 0.71), facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [16,17,18,19,20, 21, 22,23]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 12, color='lightgray', alpha=0.3)
axs.axvspan(18, 24, color='lightgray', alpha=0.3)

for i in range(0, 30, 6):
    ax2.text(i+1, 15.6, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+2, 15.6, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+3, 15.6, 'GA', ha='center', va='center', fontsize=14, color='black',rotation=90)
    ax2.text(i+4, 15.6, 'MILP', ha='center', va='center', fontsize=14, color='black',rotation=90)


for i in range(0, 30, 6):
    if i==0:
      ax2.text(i+2.5, 14.5, 'σ² = 0.1', ha='center', va='center', fontsize=16, color='black')
    elif i==6:
      ax2.text(i+2.5, 14.5, 'σ² = 0.25', ha='center', va='center', fontsize=16, color='black')
    elif i==12:
      ax2.text(i+2.5, 14.5, 'σ² = 0.5', ha='center', va='center', fontsize=16, color='black')
    elif i==18:
      ax2.text(i+2.5, 14.5, 'σ² = 0.75', ha='center', va='center', fontsize=16, color='black')
    elif i==24:
      ax2.text(i+2.5, 14.5, 'σ² = 1', ha='center', va='center', fontsize=16, color='black')

# Añadir título superior
plt.suptitle('#patients:80 #robots:8  sp = 0.65', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ1d_Robots80_p65.pdf', format='pdf')
plt.show()

# %% [markdown]
# # GRÁFICAS PARA SEAMS25
#
# Incertidumbre en la hora de3 llegada de vehículos

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos para sigma² = 0.25 y sigma² = 0.75
genetico_coste_data = [
    [85, 83, 81, 86, 82],  # σ² = 0.25
    [75, 73, 79, 76, 74]   # σ² = 0.75
]

milp_coste_data = [
    [91, 89, 88, 93, 90],  # σ² = 0.25
    [84, 79, 85, 83, 82]   # σ² = 0.75
]

genetico_coste_data2 = [
    [86] * 5,  # σ² = 0.25
    [77] * 5  # σ² = 0.75
]

milp_coste_data2 = [
    [93] * 5,  # σ² = 0.25
    [84] * 5   # σ² = 0.75
]

genetico_smc_coste_data = [
    [84] * 5,  # σ² = 0.25
    [73] * 5  # σ² = 0.75
]

genetico_timespan_data = [
    [16.8, 15.225, 15.435, 15.645, 16.065],  # σ² = 0.25
    [17.85, 17.325, 16.485, 16.695, 16.065]  # σ² = 0.75
]

milp_timespan_data = [
    [17.655, 16.364, 17.274, 17.976, 16.996],  # σ² = 0.25
    [18.832, 17.99, 18.444, 18.558, 17.976]    # σ² = 0.75
]

genetico_timespan_data2 = [
    [16.25] * 5,  # σ² = 0.25
    [17.68] * 5  # σ² = 0.75
]

milp_timespan_data2 = [
    [17.84] * 5,  # σ² = 0.25
    [18.26] * 5   # σ² = 0.75
]

genetico_smc_timespan_data = [
    [15.545] * 5,  # σ² = 0.25
    [16.758] * 5  # σ² = 0.75
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = [1, 15]
positions_milp_coste = [2, 16]
positions_genetico2_coste = [3, 17]
positions_milp2_coste = [4, 18]
positions_genetico_smc_coste = [5, 19]

positions_genetico_timespan = [7, 21]
positions_milp_timespan = [8, 22]
positions_genetico2_timespan = [9, 23]
positions_milp2_timespan = [10, 24]
positions_genetico_smc_timespan = [11, 25]

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2 = axs.boxplot(genetico_coste_data2, positions=positions_genetico2_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_milp = axs.boxplot(milp_coste_data2, positions=positions_milp2_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bpsmc = axs.boxplot(genetico_smc_coste_data, positions=positions_genetico_smc_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([65, 100])  # Ajusta el rango según tus datos
axs.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# Colorear los boxplots de coste
for box, color in zip(bp1['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bp1_milp['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bp2['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bp2_milp['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bpsmc['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)



# Boxplots para timespan en el eje derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_genetico2 = ax2.boxplot(genetico_timespan_data2, positions=positions_genetico2_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_milp2 = ax2.boxplot(milp_timespan_data2, positions=positions_milp2_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_genetico_smc = ax2.boxplot(genetico_smc_timespan_data, positions=positions_genetico_smc_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 20])  # Ajusta el rango según tus datos

# Colorear los boxplots de timespan
for box, color in zip(bp2_genetico['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_milp['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_genetico2['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_milp2['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_genetico_smc['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [75, 80, 85, 90, 95]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 13, color='lightgray', alpha=0.3)
axs.axvspan(20, 26, color='lightgray', alpha=0.3)

# Etiquetas y anotaciones
for i, sigma_label in zip([3, 18], ['σ² = 0.25', 'σ² = 0.75']):
    ax2.text(i + 2.5, 11.2, sigma_label, ha='center', va='center', fontsize=16, color='black')

for i in [0,6,14,20]:
    ax2.text(i + 1, 13, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 2, 13, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 3, 13, 'GA', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 4, 13, 'MILP', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 5.2, 13, 'GSMCA', ha='center', va='center', fontsize=12, color='brown')

for i in [0,6,14,20]:
    ax2.text(i + 1.5, 12.5, 'SIM', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 4, 12.5, 'MC', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 14]:
    ax2.text(i + 3, 11.6, 'Cost', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i + 9, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

# Título
plt.suptitle('#EVs:20 #chargers:2', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

axs.set_xlim([0, 26])  # Aumenta el rango según sea necesario

# Guardar y mostrar el gráfico
plt.savefig('Grafica_RQ12_Vehiculos20.pdf', format='pdf')
plt.show()
# Out:
# <ipython-input-3-4e613f6bd689>:73: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
# <ipython-input-3-4e613f6bd689>:74: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
# <ipython-input-3-4e613f6bd689>:75: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Nuevos datos de Disruption
genetico_coste_data = [
    [4, 5, 4, 6, 5],  # σ² = 0.25
    [5, 6, 7, 7, 6]   # σ² = 0.75
]

milp_coste_data = [
    [6, 7, 7, 8, 8],  # σ² = 0.25
    [7, 8, 8, 7, 7]   # σ² = 0.75
]

genetico_coste_data2 = [
    [4.7] * 5,  # σ² = 0.25
    [5.7] * 5   # σ² = 0.75
]

milp_coste_data2 = [
    [5.8] * 5,  # σ² = 0.25
    [7.0] * 5   # σ² = 0.75
]

genetico_smc_coste_data = [
    [4.2] * 5,  # σ² = 0.25
    [5.2] * 5   # σ² = 0.75
]

# Datos originales de Timespan (no se alteran)
genetico_timespan_data = [
    [16.8, 15.225, 15.435, 15.645, 16.065],
    [17.85, 17.325, 16.485, 16.695, 16.065]
]

milp_timespan_data = [
    [17.655, 16.364, 17.274, 17.976, 16.996],
    [18.832, 17.99, 18.444, 18.558, 17.976]
]

genetico_timespan_data2 = [
    [16.25] * 5,
    [17.68] * 5
]

milp_timespan_data2 = [
    [17.84] * 5,
    [18.26] * 5
]

genetico_smc_timespan_data = [
    [15.545] * 5,
    [16.758] * 5
]

# Gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))
ax2 = axs.twinx()

# Posiciones de los boxplots
positions_genetico_coste = [1, 15]
positions_milp_coste = [2, 16]
positions_genetico2_coste = [3, 17]
positions_milp2_coste = [4, 18]
positions_genetico_smc_coste = [5, 19]

positions_genetico_timespan = [7, 21]
positions_milp_timespan = [8, 22]
positions_genetico2_timespan = [9, 23]
positions_milp2_timespan = [10, 24]
positions_genetico_smc_timespan = [11, 25]

# Boxplots para Disruption (eje izquierdo)
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=['']*2, widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=['']*2, widths=0.4, patch_artist=True)
bp2 = axs.boxplot(genetico_coste_data2, positions=positions_genetico2_coste, labels=['']*2, widths=0.4, patch_artist=True)
bp2_milp = axs.boxplot(milp_coste_data2, positions=positions_milp2_coste, labels=['']*2, widths=0.4, patch_artist=True)
bpsmc = axs.boxplot(genetico_smc_coste_data, positions=positions_genetico_smc_coste, labels=['']*2, widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='green')
axs.set_ylim([0, 10])
axs.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

for bp in [bp1, bp1_milp, bp2, bp2_milp, bpsmc]:
    for box in bp['boxes']:
        box.set(color='green', facecolor='lightgreen')

# Boxplots para Timespan (eje derecho)
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_genetico2 = ax2.boxplot(genetico_timespan_data2, positions=positions_genetico2_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_milp2 = ax2.boxplot(milp_timespan_data2, positions=positions_milp2_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_genetico_smc = ax2.boxplot(genetico_smc_timespan_data, positions=positions_genetico_smc_timespan, labels=['']*2, widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([12, 20])

for bp in [bp2_genetico, bp2_milp, bp2_genetico2, bp2_milp2, bp2_genetico_smc]:
    for box in bp['boxes']:
        box.set(color='deeppink', facecolor='pink')

# Líneas horizontales (Disruption)
for value in range(1, 10):
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.5)

# Sombreado vertical
axs.axvspan(6, 13, color='lightgray', alpha=0.3)
axs.axvspan(20, 26, color='lightgray', alpha=0.3)

# Anotaciones
for i, sigma_label in zip([3, 18], ['σ² = 0.25', 'σ² = 0.75']):
    ax2.text(i + 2.5, 11.2, sigma_label, ha='center', va='center', fontsize=16, color='black')

for i in [0,6,14,20]:
    ax2.text(i + 1, 13, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 2, 13, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 3, 13, 'GA', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 4, 13, 'MILP', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 5.2, 13, 'GSMCA', ha='center', va='center', fontsize=12, color='brown')

for i in [0,6,14,20]:
    ax2.text(i + 1.5, 12.5, 'SIM', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 4, 12.5, 'MC', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 14]:
    ax2.text(i + 3, 11.6, 'Disruption', ha='center', va='center', fontsize=12, color='green')
    ax2.text(i + 9, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='deeppink')

plt.suptitle('#patients:20 #robots:2', fontsize=20, y=0.92)

axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)
axs.set_xlim([0, 26])

# Guardar y mostrar
plt.savefig('Grafica_RQ12_RoboMAX20.pdf', format='pdf')
plt.show()
# Out:
# <ipython-input-14-049bf6e454b9>:74: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=['']*2, widths=0.4, patch_artist=True)
# <ipython-input-14-049bf6e454b9>:75: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=['']*2, widths=0.4, patch_artist=True)
# <ipython-input-14-049bf6e454b9>:76: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp2 = axs.boxplot(genetico_coste_data2, positions=positions_genetico2_coste, labels=['']*2, widths=0.4, patch_artist=True)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# === DATOS FICTICIOS DE AGRICULTURA PARA σ² = 0.25 y σ² = 0.75 ===

genetico_water_data = [
    [3.2, 3.1, 3.3, 3.0, 3.4],   # σ² = 0.25
    [3.8, 3.7, 3.6, 3.9, 3.5]    # σ² = 0.75
]

milp_water_data = [
    [3.6, 3.5, 3.7, 3.8, 3.6],   # σ² = 0.25
    [4.0, 3.9, 4.1, 3.8, 4.2]    # σ² = 0.75
]

genetico_water_data2 = [
    [3.3] * 5,  # σ² = 0.25
    [3.7] * 5   # σ² = 0.75
]

milp_water_data2 = [
    [3.5] * 5,  # σ² = 0.25
    [4.0] * 5   # σ² = 0.75
]

genetico_smc_water_data = [
    [3.1] * 5,  # σ² = 0.25
    [3.6] * 5   # σ² = 0.75
]

genetico_timespan_data = [
    [17.0, 16.5, 16.7, 17.2, 16.8],
    [18.0, 17.9, 18.1, 17.7, 18.2]
]

milp_timespan_data = [
    [18.4, 18.6, 18.2, 18.8, 18.7],
    [19.5, 19.3, 19.6, 19.1, 19.8]
]

genetico_timespan_data2 = [
    [16.9] * 5,
    [17.8] * 5
]

milp_timespan_data2 = [
    [18.1] * 5,
    [19.4] * 5
]

genetico_smc_timespan_data = [
    [16.6] * 5,
    [17.3] * 5
]

# === COLORES PERSONALIZADOS ===
color_water = '#b39ddb'
color_water_fill = '#d1c4e9'
color_time = '#388e3c'
color_time_fill = '#a5d6a7'

# === GRÁFICO ===
fig, axs = plt.subplots(1, 1, figsize=(16, 8))
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_water = [1, 15]
positions_milp_water = [2, 16]
positions_genetico2_water = [3, 17]
positions_milp2_water = [4, 18]
positions_smc_water = [5, 19]

positions_genetico_time = [7, 21]
positions_milp_time = [8, 22]
positions_genetico2_time = [9, 23]
positions_milp2_time = [10, 24]
positions_smc_time = [11, 25]

# === BOXES: WATER USE ===
bp1 = axs.boxplot(genetico_water_data, positions=positions_genetico_water, widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_water_data, positions=positions_milp_water, widths=0.4, patch_artist=True)
bp2 = axs.boxplot(genetico_water_data2, positions=positions_genetico2_water, widths=0.4, patch_artist=True)
bp2_milp = axs.boxplot(milp_water_data2, positions=positions_milp2_water, widths=0.4, patch_artist=True)
bpsmc = axs.boxplot(genetico_smc_water_data, positions=positions_smc_water, widths=0.4, patch_artist=True)

axs.set_ylabel('Water use (m³)', fontsize=20, color=color_water)
axs.set_ylim([2.5, 4.5])
axs.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

for bp in [bp1, bp1_milp, bp2, bp2_milp, bpsmc]:
    for box in bp['boxes']:
        box.set(color=color_water, facecolor=color_water_fill)

# === BOXES: TIMESPAN ===
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_time, widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_time, widths=0.4, patch_artist=True)
bp2_genetico2 = ax2.boxplot(genetico_timespan_data2, positions=positions_genetico2_time, widths=0.4, patch_artist=True)
bp2_milp2 = ax2.boxplot(milp_timespan_data2, positions=positions_milp2_time, widths=0.4, patch_artist=True)
bp2_smc = ax2.boxplot(genetico_smc_timespan_data, positions=positions_smc_time, widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan (h)', fontsize=20, color=color_time)
ax2.set_ylim([15, 20])

for bp in [bp2_genetico, bp2_milp, bp2_genetico2, bp2_milp2, bp2_smc]:
    for box in bp['boxes']:
        box.set(color=color_time, facecolor=color_time_fill)

# === LÍNEAS DE REFERENCIA PARA AGUA ===
for value in [3.0, 3.5, 4.0]:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# === SOMBREADO VERTICAL PARA TIMESPAN ===
axs.axvspan(6, 13, color='lightgray', alpha=0.3)
axs.axvspan(20, 26, color='lightgray', alpha=0.3)

# === ANOTACIONES ===
for i, sigma_label in zip([3, 18], ['σ² = 0.25', 'σ² = 0.75']):
    ax2.text(i + 2.5, 14.4, sigma_label, ha='center', va='center', fontsize=16, color='black')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1, 15.6, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 2, 15.6, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 3, 15.6, 'GA', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 4, 15.6, 'MILP', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 5.2, 15.6, 'GSMCA', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1.5, 15.2, 'SIM', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 4, 15.2, 'MC', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 14]:
    ax2.text(i + 3, 14.8, 'Water use', ha='center', va='center', fontsize=12, color=color_water)
    ax2.text(i + 9, 14.8, 'Timespan', ha='center', va='center', fontsize=12, color=color_time)

# === TÍTULO Y AXIS ===
plt.suptitle('#crops:20 #robots:2', fontsize=20, y=0.92)
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)
axs.set_xlim([0, 26])

# === GUARDAR Y MOSTRAR ===
plt.savefig('Grafica_RQ12_Agricultura20.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos para sigma² = 0.25 y sigma² = 0.75
genetico_coste_data = [
    [320, 316, 312, 322, 314],  # σ² = 0.25
    [300, 296, 308, 302, 298]   # σ² = 0.75
]

milp_coste_data = [
    [332, 328, 326, 336, 330],  # σ² = 0.25
    [318, 308, 320, 316, 314]   # σ² = 0.75
]

genetico_coste_data2 = [
    [320] * 5,  # σ² = 0.25
    [304] * 5  # σ² = 0.75
]

milp_coste_data2 = [
    [329] * 5,  # σ² = 0.25
    [322] * 5   # σ² = 0.75
]

genetico_smc_coste_data = [
    [315] * 5,  # σ² = 0.25
    [300] * 5  # σ² = 0.75
]

genetico_timespan_data = [
    [17.0, 15.7, 16.7, 17.3, 16.3],  # σ² = 0.25
    [18.1, 17.5, 17.7, 17.9, 17.3]  # σ² = 0.75
]

milp_timespan_data = [
    [19.7, 17.9, 18.14, 18.38, 18.86],  # σ² = 0.25
    [20.9, 20.3, 19.34, 19.58, 18.86]    # σ² = 0.75
]

genetico_timespan_data2 = [
    [17.1] * 5,  # σ² = 0.25
    [17.9] * 5  # σ² = 0.75
]

milp_timespan_data2 = [
    [18.6] * 5,  # σ² = 0.25
    [20.2] * 5   # σ² = 0.75
]

genetico_smc_timespan_data = [
    [16.4] * 5,  # σ² = 0.25
    [17.5] * 5  # σ² = 0.75
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = [1, 15]
positions_milp_coste = [2, 16]
positions_genetico2_coste = [3, 17]
positions_milp2_coste = [4, 18]
positions_genetico_smc_coste = [5, 19]

positions_genetico_timespan = [7, 21]
positions_milp_timespan = [8, 22]
positions_genetico2_timespan = [9, 23]
positions_milp2_timespan = [10, 24]
positions_genetico_smc_timespan = [11, 25]

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2 = axs.boxplot(genetico_coste_data2, positions=positions_genetico2_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_milp = axs.boxplot(milp_coste_data2, positions=positions_milp2_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bpsmc = axs.boxplot(genetico_smc_coste_data, positions=positions_genetico_smc_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([280, 340])  # Ajusta el rango según tus datos
axs.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# Colorear los boxplots de coste
for box, color in zip(bp1['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bp1_milp['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bp2['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bp2_milp['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bpsmc['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)



# Boxplots para timespan en el eje derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_genetico2 = ax2.boxplot(genetico_timespan_data2, positions=positions_genetico2_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_milp2 = ax2.boxplot(milp_timespan_data2, positions=positions_milp2_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_genetico_smc = ax2.boxplot(genetico_smc_timespan_data, positions=positions_genetico_smc_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 22])  # Ajusta el rango según tus datos

# Colorear los boxplots de timespan
for box, color in zip(bp2_genetico['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_milp['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_genetico2['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_milp2['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_genetico_smc['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [300, 310, 320, 330]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 13, color='lightgray', alpha=0.3)
axs.axvspan(20, 26, color='lightgray', alpha=0.3)

# Etiquetas y anotaciones
for i, sigma_label in zip([3, 18], ['σ² = 0.25', 'σ² = 0.75']):
    ax2.text(i + 2.5, 11, sigma_label, ha='center', va='center', fontsize=16, color='black')

for i in [0,6,14,20]:
    ax2.text(i + 1, 13, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 2, 13, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 3, 13, 'GA', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 4, 13, 'MILP', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 5.2, 13, 'GSMCA', ha='center', va='center', fontsize=12, color='brown')

for i in [0,6,14,20]:
    ax2.text(i + 1.5, 12.5, 'SIM', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 4, 12.5, 'MC', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 14]:
    ax2.text(i + 3, 11.6, 'Cost', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i + 9, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')


# Título
plt.suptitle('#EVs:80 #chargers:8', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

axs.set_xlim([0, 26])  # Aumenta el rango según sea necesario

# Guardar y mostrar el gráfico
plt.savefig('Grafica_RQ12_Vehiculos80.pdf', format='pdf')
plt.show()
# Out:
# <ipython-input-13-25a0676e4e5f>:73: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
# <ipython-input-13-25a0676e4e5f>:74: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
# <ipython-input-13-25a0676e4e5f>:75: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos simulados para 80 pacientes y 8 robots, ajustados a las nuevas escalas
# Disruption: entre 15 y 30, Timespan: entre 12 y 22

# Disruption data (ajustados para 80 pacientes y 8 robots)
genetico_coste_data = [
    [19, 20, 18, 18, 17],  # σ² = 0.25 (GA siempre mejor que MILP)
    [22, 23, 22, 21, 23]   # σ² = 0.75 (GA siempre mejor que MILP)
]

milp_coste_data = [
    [19, 20, 22, 21, 22],  # σ² = 0.25 (MILP)
    [26, 24, 25, 24, 26]   # σ² = 0.75 (MILP)
]

genetico_coste_data2 = [
    [19.0] * 5,  # σ² = 0.25 (GA constante)
    [22.0] * 5   # σ² = 0.75 (GA constante)
]

milp_coste_data2 = [
    [21] * 5,  # σ² = 0.25 (MILP constante)
    [24] * 5   # σ² = 0.75 (MILP constante)
]

genetico_smc_coste_data = [
    [17] * 5,  # σ² = 0.25 (GSMCA siempre el mejor)
    [21] * 5   # σ² = 0.75 (GSMCA siempre el mejor)
]

# Timespan data (ajustados para 80 pacientes y 8 robots)
genetico_timespan_data = [
    [18.2, 16.725, 17.435, 17.645, 17.065],  # σ² = 0.25 (GA siempre mejor que MILP)
    [19.85, 19.825, 18.985, 19.195, 18.565]   # σ² = 0.75 (GA siempre mejor que MILP)
]

milp_timespan_data = [
    [20.155, 18.364, 19.274, 20.476, 19.996],  # σ² = 0.25 (MILP)
    [20.832, 20.49, 20.944, 21.058, 20.476]   # σ² = 0.75 (MILP)
]

genetico_timespan_data2 = [
    [17.0] * 5,  # σ² = 0.25 (GA constante)
    [19.0] * 5   # σ² = 0.75 (GA constante)
]

milp_timespan_data2 = [
    [18.5] * 5,  # σ² = 0.25 (MILP constante)
    [20.5] * 5   # σ² = 0.75 (MILP constante)
]

genetico_smc_timespan_data = [
    [15.8] * 5,  # σ² = 0.25 (GSMCA siempre el mejor)
    [17.8] * 5   # σ² = 0.75 (GSMCA siempre el mejor)
]

# Gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))
ax2 = axs.twinx()

# Posiciones de los boxplots
positions_genetico_coste = [1, 15]
positions_milp_coste = [2, 16]
positions_genetico2_coste = [3, 17]
positions_milp2_coste = [4, 18]
positions_genetico_smc_coste = [5, 19]

positions_genetico_timespan = [7, 21]
positions_milp_timespan = [8, 22]
positions_genetico2_timespan = [9, 23]
positions_milp2_timespan = [10, 24]
positions_genetico_smc_timespan = [11, 25]

# Boxplots para Disruption (eje izquierdo)
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=['']*2, widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=['']*2, widths=0.4, patch_artist=True)
bp2 = axs.boxplot(genetico_coste_data2, positions=positions_genetico2_coste, labels=['']*2, widths=0.4, patch_artist=True)
bp2_milp = axs.boxplot(milp_coste_data2, positions=positions_milp2_coste, labels=['']*2, widths=0.4, patch_artist=True)
bpsmc = axs.boxplot(genetico_smc_coste_data, positions=positions_genetico_smc_coste, labels=['']*2, widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='green')
axs.set_ylim([15, 30])  # Nuevo rango para Disruption
axs.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

for bp in [bp1, bp1_milp, bp2, bp2_milp, bpsmc]:
    for box in bp['boxes']:
        box.set(color='green', facecolor='lightgreen')

# Boxplots para Timespan (eje derecho)
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_genetico2 = ax2.boxplot(genetico_timespan_data2, positions=positions_genetico2_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_milp2 = ax2.boxplot(milp_timespan_data2, positions=positions_milp2_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_genetico_smc = ax2.boxplot(genetico_smc_timespan_data, positions=positions_genetico_smc_timespan, labels=['']*2, widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([12, 22])  # Nuevo rango para Timespan

for bp in [bp2_genetico, bp2_milp, bp2_genetico2, bp2_milp2, bp2_genetico_smc]:
    for box in bp['boxes']:
        box.set(color='deeppink', facecolor='pink')

# Líneas horizontales (Disruption)
for value in range(15, 31, 3):
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.5)

# Sombreado vertical
axs.axvspan(6, 13, color='lightgray', alpha=0.3)
axs.axvspan(20, 26, color='lightgray', alpha=0.3)

# Anotaciones
for i, sigma_label in zip([3, 18], ['σ² = 0.25', 'σ² = 0.75']):
    ax2.text(i + 2.5, 11.2, sigma_label, ha='center', va='center', fontsize=16, color='black')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1, 13, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 2, 13, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 3, 13, 'GA', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 4, 13, 'MILP', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 5.2, 13, 'GSMCA', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1.5, 12.5, 'SIM', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 4, 12.5, 'MC', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 14]:
    ax2.text(i + 3, 11.6, 'Disruption', ha='center', va='center', fontsize=12, color='green')
    ax2.text(i + 9, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='deeppink')

plt.suptitle('#patients:80 #robots:8', fontsize=20, y=0.92)

axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)
axs.set_xlim([0, 26])

# Guardar y mostrar
plt.savefig('Grafica_RQ12_RoboMAX80.pdf', format='pdf')
plt.show()
# Out:
# <ipython-input-15-4a63c0a59b3d>:77: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=['']*2, widths=0.4, patch_artist=True)
# <ipython-input-15-4a63c0a59b3d>:78: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=['']*2, widths=0.4, patch_artist=True)
# <ipython-input-15-4a63c0a59b3d>:79: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp2 = axs.boxplot(genetico_coste_data2, positions=positions_genetico2_coste, labels=['']*2, widths=0.4, patch_artist=True)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# === DATOS FICTICIOS DE AGRICULTURA PARA σ² = 0.25 y σ² = 0.75 ===

genetico_water_data = [
    [13.5, 13.4, 13.7, 13.2, 13.9],  # σ² = 0.25
    [14.5, 14.0, 14.3, 14.1, 14.8]   # σ² = 0.75
]

milp_water_data = [
    [14.3, 13.9, 14.1, 14.5, 14.1],  # σ² = 0.25
    [14.7, 14.6, 14.8, 14.5, 14.9]   # σ² = 0.75
]

genetico_water_data2 = [
    [13.4] * 5,  # σ² = 0.25
    [14.1] * 5   # σ² = 0.75
]

milp_water_data2 = [
    [13.9] * 5,  # σ² = 0.25
    [14.6] * 5   # σ² = 0.75
]

genetico_smc_water_data = [
    [13.2] * 5,  # σ² = 0.25
    [13.8] * 5   # σ² = 0.75
]

genetico_timespan_data = [
    [19.0, 18.7, 18.9, 19.2, 18.8],
    [20.0, 19.8, 20.1, 19.7, 20.2]
]

milp_timespan_data = [
    [20.2, 20.3, 20.5, 19.9, 20.6],
    [21.1,20.9, 21.4, 21.1, 20.7]
]

genetico_timespan_data2 = [
    [18.6] * 5,
    [19.5] * 5
]

milp_timespan_data2 = [
    [20.0] * 5,
    [21.3] * 5
]

genetico_smc_timespan_data = [
    [18.2] * 5,
    [19.0] * 5
]

# === COLORES PERSONALIZADOS ===
color_water = '#b39ddb'
color_water_fill = '#d1c4e9'
color_time = '#388e3c'
color_time_fill = '#a5d6a7'

# === GRÁFICO ===
fig, axs = plt.subplots(1, 1, figsize=(16, 8))
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_water = [1, 15]
positions_milp_water = [2, 16]
positions_genetico2_water = [3, 17]
positions_milp2_water = [4, 18]
positions_smc_water = [5, 19]

positions_genetico_time = [7, 21]
positions_milp_time = [8, 22]
positions_genetico2_time = [9, 23]
positions_milp2_time = [10, 24]
positions_smc_time = [11, 25]

# === BOXES: WATER USE ===
bp1 = axs.boxplot(genetico_water_data, positions=positions_genetico_water, widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_water_data, positions=positions_milp_water, widths=0.4, patch_artist=True)
bp2 = axs.boxplot(genetico_water_data2, positions=positions_genetico2_water, widths=0.4, patch_artist=True)
bp2_milp = axs.boxplot(milp_water_data2, positions=positions_milp2_water, widths=0.4, patch_artist=True)
bpsmc = axs.boxplot(genetico_smc_water_data, positions=positions_smc_water, widths=0.4, patch_artist=True)

axs.set_ylabel('Water use (m³)', fontsize=20, color=color_water)
axs.set_ylim([12,16])
axs.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

for bp in [bp1, bp1_milp, bp2, bp2_milp, bpsmc]:
    for box in bp['boxes']:
        box.set(color=color_water, facecolor=color_water_fill)

# === BOXES: TIMESPAN ===
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_time, widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_time, widths=0.4, patch_artist=True)
bp2_genetico2 = ax2.boxplot(genetico_timespan_data2, positions=positions_genetico2_time, widths=0.4, patch_artist=True)
bp2_milp2 = ax2.boxplot(milp_timespan_data2, positions=positions_milp2_time, widths=0.4, patch_artist=True)
bp2_smc = ax2.boxplot(genetico_smc_timespan_data, positions=positions_smc_time, widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan (h)', fontsize=20, color=color_time)
ax2.set_ylim([15, 22])

for bp in [bp2_genetico, bp2_milp, bp2_genetico2, bp2_milp2, bp2_smc]:
    for box in bp['boxes']:
        box.set(color=color_time, facecolor=color_time_fill)

# === LÍNEAS DE REFERENCIA PARA AGUA ===
for value in [12.0, 13.0, 14.0, 15.0]:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# === SOMBREADO VERTICAL PARA TIMESPAN ===
axs.axvspan(6, 13, color='lightgray', alpha=0.3)
axs.axvspan(20, 26, color='lightgray', alpha=0.3)

# === ANOTACIONES ===
for i, sigma_label in zip([3, 18], ['σ² = 0.25', 'σ² = 0.75']):
    ax2.text(i + 2.5, 14.4, sigma_label, ha='center', va='center', fontsize=16, color='black')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1, 15.6, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 2, 15.6, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 3, 15.6, 'GA', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 4, 15.6, 'MILP', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 5.2, 15.6, 'GSMCA', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1.5, 15.2, 'SIM', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 4, 15.2, 'MC', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 14]:
    ax2.text(i + 3, 14.8, 'Water use', ha='center', va='center', fontsize=12, color=color_water)
    ax2.text(i + 9, 14.8, 'Timespan', ha='center', va='center', fontsize=12, color=color_time)

# === TÍTULO Y AXIS ===
plt.suptitle('#crops:80 #robots:8', fontsize=20, y=0.92)
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)
axs.set_xlim([0, 26])

# === GUARDAR Y MOSTRAR ===
plt.savefig('Grafica_RQ12_Agricultura80.pdf', format='pdf')
plt.show()

# %% [markdown]
# Combinación de incertidumbres

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos para sigma² = 0.25 y sigma² = 0.75
genetico_coste_data = [
    [344, 349, 357, 347, 354],  # σ² = 0.25
    [372, 362, 368, 360, 365]   # σ² = 0.75
]

milp_coste_data = [
    [382, 386, 392, 396, 390],  # σ² = 0.25
    [414, 410, 406, 416, 409]   # σ² = 0.75
]

genetico_coste_data2 = [
    [354] * 5,  # σ² = 0.25
    [371] * 5  # σ² = 0.75
]

milp_coste_data2 = [
    [390] * 5,  # σ² = 0.25
    [415] * 5   # σ² = 0.75
]

genetico_smc_coste_data = [
    [344] * 5,  # σ² = 0.25
    [357] * 5  # σ² = 0.75
]

genetico_timespan_data = [
    [17.0, 17.5, 16.7, 17.3, 16.9],  # σ² = 0.25
    [17.85, 18.5, 18.31, 17.65, 18.1]  # σ² = 0.75
]

milp_timespan_data = [
    [20.1, 19.3, 19.2, 19.78, 19.5],  # σ² = 0.25
    [21.05, 21.3, 21.44, 21.6, 20.75]    # σ² = 0.75
]

genetico_timespan_data2 = [
    [17.3] * 5,  # σ² = 0.25
    [19.1] * 5  # σ² = 0.75
]

milp_timespan_data2 = [
    [20.4] * 5,  # σ² = 0.25
    [21.6] * 5   # σ² = 0.75
]

genetico_smc_timespan_data = [
    [16.4] * 5,  # σ² = 0.25
    [18.1] * 5  # σ² = 0.75
]

# Configuración del gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_coste = [1, 15]
positions_milp_coste = [2, 16]
positions_genetico2_coste = [3, 17]
positions_milp2_coste = [4, 18]
positions_genetico_smc_coste = [5, 19]

positions_genetico_timespan = [7, 21]
positions_milp_timespan = [8, 22]
positions_genetico2_timespan = [9, 23]
positions_milp2_timespan = [10, 24]
positions_genetico_smc_timespan = [11, 25]

# Boxplots para el coste en el eje izquierdo
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2 = axs.boxplot(genetico_coste_data2, positions=positions_genetico2_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_milp = axs.boxplot(milp_coste_data2, positions=positions_milp2_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bpsmc = axs.boxplot(genetico_smc_coste_data, positions=positions_genetico_smc_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)

axs.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')
axs.set_ylim([310, 420])  # Ajusta el rango según tus datos
axs.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# Colorear los boxplots de coste
for box, color in zip(bp1['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bp1_milp['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bp2['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bp2_milp['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)

for box, color in zip(bpsmc['boxes'], ['lightblue'] * 2):
    box.set(color='blue', facecolor=color)



# Boxplots para timespan en el eje derecho
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_genetico2 = ax2.boxplot(genetico_timespan_data2, positions=positions_genetico2_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_milp2 = ax2.boxplot(milp_timespan_data2, positions=positions_milp2_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
bp2_genetico_smc = ax2.boxplot(genetico_smc_timespan_data, positions=positions_genetico_smc_timespan, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
ax2.set_ylim([12, 24])  # Ajusta el rango según tus datos

# Colorear los boxplots de timespan
for box, color in zip(bp2_genetico['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_milp['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_genetico2['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_milp2['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

for box, color in zip(bp2_genetico_smc['boxes'], ['lightsalmon'] * 2):
    box.set(color='red', facecolor=color)

# Añadir líneas horizontales para valores específicos de costo
cost_values = [340, 360, 380, 400, 420]  # Lista de valores de costo
for value in cost_values:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# Añadir sombreado vertical
axs.axvspan(6, 13, color='lightgray', alpha=0.3)
axs.axvspan(20, 26, color='lightgray', alpha=0.3)

# Etiquetas y anotaciones
for i, sigma_label in zip([3, 18], ['σ² = 0.25', 'σ² = 0.75']):
    ax2.text(i + 2.5, 11, sigma_label, ha='center', va='center', fontsize=16, color='black')

for i in [0,6,14,20]:
    ax2.text(i + 1, 13, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 2, 13, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 3, 13, 'GA', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 4, 13, 'MILP', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 5.2, 13, 'GSMCA', ha='center', va='center', fontsize=12, color='brown')

for i in [0,6,14,20]:
    ax2.text(i + 1.5, 12.5, 'SIM', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 4, 12.5, 'MC', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 14]:
    ax2.text(i + 3, 11.6, 'Cost', ha='center', va='center', fontsize=12, color='blue')
    ax2.text(i + 9, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='red')

# Título
plt.suptitle('#EVs:80 #chargers:8 s.p = 0.25', fontsize=20, y=0.92)

# Ajusta el tamaño de las etiquetas de los ejes
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)

# Ajustar el límite del eje x
axs.set_xlim([0, 26])  # Aumenta el rango según sea necesario

# Guardar y mostrar el gráfico
plt.savefig('Grafica_RQ14_Vehiculos80_p25.pdf', format='pdf')
plt.show()
# Out:
# <ipython-input-18-d0c254e66590>:73: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
# <ipython-input-18-d0c254e66590>:74: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
# <ipython-input-18-d0c254e66590>:75: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Nuevos datos para 80 pacientes y 8 robots (ajustados)
# Disruption (coste): aumentados, enteros
genetico_coste_data = [
    [21, 22, 20, 20, 19],  # σ² = 0.25
    [24, 25, 24, 23, 25]   # σ² = 0.75
]

milp_coste_data = [
    [26, 27, 28, 27, 26],  # σ² = 0.25 (aumentamos la diferencia)
    [30, 31, 29, 30, 32]   # σ² = 0.75
]

genetico_coste_data2 = [
    [21] * 5,  # σ² = 0.25
    [24] * 5   # σ² = 0.75
]

milp_coste_data2 = [
    [27] * 5,  # σ² = 0.25
    [31] * 5   # σ² = 0.75
]

genetico_smc_coste_data = [
    [18] * 5,  # σ² = 0.25
    [22] * 5   # σ² = 0.75
]

# Timespan (horas): aumentados ligeramente
genetico_timespan_data = [
    [17.3, 17.5, 16.7, 17.5, 16.9],  # σ² = 0.25
    [17.85, 18.5, 18.31, 17.65, 18.1]  # σ² = 0.75
]

milp_timespan_data = [
    [20.1, 19.2, 19.6, 19.78, 19.5],  # σ² = 0.25
    [21.2, 21.3, 21.7, 21.6, 20.75]    # σ² = 0.75
]

genetico_timespan_data2 = [
    [17.1] * 5,  # σ² = 0.25
    [19.2] * 5  # σ² = 0.75
]

milp_timespan_data2 = [
    [20.5] * 5,  # σ² = 0.25
    [21.2] * 5   # σ² = 0.75
]

genetico_smc_timespan_data = [
    [16.7] * 5,  # σ² = 0.25
    [18.2] * 5  # σ² = 0.75
]

# Gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))
ax2 = axs.twinx()

# Posiciones de los boxplots
positions_genetico_coste = [1, 15]
positions_milp_coste = [2, 16]
positions_genetico2_coste = [3, 17]
positions_milp2_coste = [4, 18]
positions_genetico_smc_coste = [5, 19]

positions_genetico_timespan = [7, 21]
positions_milp_timespan = [8, 22]
positions_genetico2_timespan = [9, 23]
positions_milp2_timespan = [10, 24]
positions_genetico_smc_timespan = [11, 25]

# Boxplots para Disruption (eje izquierdo)
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=['']*2, widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=['']*2, widths=0.4, patch_artist=True)
bp2 = axs.boxplot(genetico_coste_data2, positions=positions_genetico2_coste, labels=['']*2, widths=0.4, patch_artist=True)
bp2_milp = axs.boxplot(milp_coste_data2, positions=positions_milp2_coste, labels=['']*2, widths=0.4, patch_artist=True)
bpsmc = axs.boxplot(genetico_smc_coste_data, positions=positions_genetico_smc_coste, labels=['']*2, widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='green')
axs.set_ylim([14, 35])  # Nuevo rango para Disruption
axs.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

for bp in [bp1, bp1_milp, bp2, bp2_milp, bpsmc]:
    for box in bp['boxes']:
        box.set(color='green', facecolor='lightgreen')

# Boxplots para Timespan (eje derecho)
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_genetico2 = ax2.boxplot(genetico_timespan_data2, positions=positions_genetico2_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_milp2 = ax2.boxplot(milp_timespan_data2, positions=positions_milp2_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_genetico_smc = ax2.boxplot(genetico_smc_timespan_data, positions=positions_genetico_smc_timespan, labels=['']*2, widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([12, 22])  # Nuevo rango para Timespan

for bp in [bp2_genetico, bp2_milp, bp2_genetico2, bp2_milp2, bp2_genetico_smc]:
    for box in bp['boxes']:
        box.set(color='deeppink', facecolor='pink')

# Líneas horizontales (Disruption)
for value in range(15, 35, 3):
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.5)

# Sombreado vertical
axs.axvspan(6, 13, color='lightgray', alpha=0.3)
axs.axvspan(20, 26, color='lightgray', alpha=0.3)

# Anotaciones
for i, sigma_label in zip([3, 18], ['σ² = 0.25', 'σ² = 0.75']):
    ax2.text(i + 2.5, 11.2, sigma_label, ha='center', va='center', fontsize=16, color='black')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1, 13, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 2, 13, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 3, 13, 'GA', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 4, 13, 'MILP', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 5.2, 13, 'GSMCA', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1.5, 12.5, 'SIM', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 4, 12.5, 'MC', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 14]:
    ax2.text(i + 3, 11.6, 'Disruption', ha='center', va='center', fontsize=12, color='green')
    ax2.text(i + 9, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='deeppink')

plt.suptitle('#patients:80 #robots:8 s.p = 0.25', fontsize=20, y=0.92)

axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)
axs.set_xlim([0, 26])

# Guardar y mostrar
plt.savefig('Grafica_RQ14_RoboMAX80_p25.pdf', format='pdf')
plt.show()
# Out:
# <ipython-input-18-ac7f20072fae>:75: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=['']*2, widths=0.4, patch_artist=True)
# <ipython-input-18-ac7f20072fae>:76: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=['']*2, widths=0.4, patch_artist=True)
# <ipython-input-18-ac7f20072fae>:77: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp2 = axs.boxplot(genetico_coste_data2, positions=positions_genetico2_coste, labels=['']*2, widths=0.4, patch_artist=True)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np



genetico_water_data = [
    [13.8, 13.6, 13.9, 13.7, 13.5],  # σ² = 0.25
    [14.6, 14.3, 14.4, 14.7, 14.2]   # σ² = 0.75
]

milp_water_data = [
    [14.4, 14.2, 14.5, 14.6, 14.3],  # σ² = 0.25
    [15.0, 14.9, 14.8, 15.1, 14.7]   # σ² = 0.75
]

# === Constantes ===
genetico_water_data2 = [
    [13.6] * 5,  # σ² = 0.25
    [14.1] * 5   # σ² = 0.75
]

milp_water_data2 = [
    [14.2] * 5,  # σ² = 0.25
    [14.8] * 5   # σ² = 0.75
]

genetico_smc_water_data = [
    [13.3] * 5,  # σ² = 0.25
    [13.9] * 5   # σ² = 0.75
]

# === Tiempo ===
genetico_timespan_data = [
    [19.5, 19.2, 19.4, 19.6, 19.3],
    [20.6, 20.4, 20.7, 20.3, 20.8]
]

milp_timespan_data = [
    [21.4, 20.9, 21.3, 21.5, 21.1],
    [22.4, 22.2, 22.6, 22.1, 22.3]
]

# === Constantes ===
genetico_timespan_data2 = [
    [19.0] * 5,
    [19.8] * 5
]

milp_timespan_data2 = [
    [21.1] * 5,
    [22.2] * 5
]

genetico_smc_timespan_data = [
    [18.4] * 5,
    [19.2] * 5
]

# === COLORES PERSONALIZADOS ===
color_water = '#b39ddb'
color_water_fill = '#d1c4e9'
color_time = '#388e3c'
color_time_fill = '#a5d6a7'

# === GRÁFICO ===
fig, axs = plt.subplots(1, 1, figsize=(16, 8))
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_water = [1, 15]
positions_milp_water = [2, 16]
positions_genetico2_water = [3, 17]
positions_milp2_water = [4, 18]
positions_smc_water = [5, 19]

positions_genetico_time = [7, 21]
positions_milp_time = [8, 22]
positions_genetico2_time = [9, 23]
positions_milp2_time = [10, 24]
positions_smc_time = [11, 25]

# === BOXES: WATER USE ===
bp1 = axs.boxplot(genetico_water_data, positions=positions_genetico_water, widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_water_data, positions=positions_milp_water, widths=0.4, patch_artist=True)
bp2 = axs.boxplot(genetico_water_data2, positions=positions_genetico2_water, widths=0.4, patch_artist=True)
bp2_milp = axs.boxplot(milp_water_data2, positions=positions_milp2_water, widths=0.4, patch_artist=True)
bpsmc = axs.boxplot(genetico_smc_water_data, positions=positions_smc_water, widths=0.4, patch_artist=True)

axs.set_ylabel('Water use (m³)', fontsize=20, color=color_water)
axs.set_ylim([12, 16])
axs.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

for bp in [bp1, bp1_milp, bp2, bp2_milp, bpsmc]:
    for box in bp['boxes']:
        box.set(color=color_water, facecolor=color_water_fill)

# === BOXES: TIMESPAN ===
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_time, widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_time, widths=0.4, patch_artist=True)
bp2_genetico2 = ax2.boxplot(genetico_timespan_data2, positions=positions_genetico2_time, widths=0.4, patch_artist=True)
bp2_milp2 = ax2.boxplot(milp_timespan_data2, positions=positions_milp2_time, widths=0.4, patch_artist=True)
bp2_smc = ax2.boxplot(genetico_smc_timespan_data, positions=positions_smc_time, widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan (h)', fontsize=20, color=color_time)
ax2.set_ylim([16, 23])

for bp in [bp2_genetico, bp2_milp, bp2_genetico2, bp2_milp2, bp2_smc]:
    for box in bp['boxes']:
        box.set(color=color_time, facecolor=color_time_fill)

# === LÍNEAS DE REFERENCIA PARA AGUA ===
for value in [12.0, 13.0, 14.0, 15.0]:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# === SOMBREADO VERTICAL PARA TIMESPAN ===
axs.axvspan(6, 13, color='lightgray', alpha=0.3)
axs.axvspan(20, 26, color='lightgray', alpha=0.3)

# === ANOTACIONES ===
for i, sigma_label in zip([3, 18], ['σ² = 0.25', 'σ² = 0.75']):
    ax2.text(i + 2.5, 15.4, sigma_label, ha='center', va='center', fontsize=16, color='black')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1, 16.6, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 2, 16.6, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 3, 16.6, 'GA', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 4, 16.6, 'MILP', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 5.2, 16.6, 'GSMCA', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1.5, 16.2, 'SIM', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 4, 16.2, 'MC', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 14]:
    ax2.text(i + 3, 15.8, 'Water use', ha='center', va='center', fontsize=12, color=color_water)
    ax2.text(i + 9, 15.8, 'Timespan', ha='center', va='center', fontsize=12, color=color_time)

# === TÍTULO Y AXIS ===
plt.suptitle('#crops:80 #robots:8 s.p = 0.25', fontsize=20, y=0.92)
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)
axs.set_xlim([0, 26])

# === GUARDAR Y MOSTRAR ===
plt.savefig('Grafica_RQ14_Agricultura80_p25.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# Out:
# <ipython-input-23-b483cf7cf3cf>:73: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
# <ipython-input-23-b483cf7cf3cf>:74: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=[' ' for _ in range(2)], widths=0.4, patch_artist=True)
# <ipython-input-23-b483cf7cf3cf>:75: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Disruption (coste) - enteros
genetico_coste_data = [
    [23, 24, 22, 22, 21],  # σ² = 0.25
    [26, 27, 26, 25, 27]   # σ² = 0.75
]

milp_coste_data = [
    [29, 30, 31, 30, 29],  # σ² = 0.25
    [33, 34, 32, 33, 35]   # σ² = 0.75
]

genetico_coste_data2 = [
    [23] * 5,  # σ² = 0.25
    [26] * 5   # σ² = 0.75
]

milp_coste_data2 = [
    [30] * 5,  # σ² = 0.25
    [34] * 5   # σ² = 0.75
]

genetico_smc_coste_data = [
    [20] * 5,  # σ² = 0.25
    [24] * 5   # σ² = 0.75
]

# Timespan (horas) - aumentados
genetico_timespan_data = [
    [17.8, 18.0, 17.3, 18.0, 17.5],       # σ² = 0.25
    [18.8, 19.4, 19.2, 18.5, 18.9]        # σ² = 0.75
]

milp_timespan_data = [
    [20.7, 19.8, 20.2, 20.3, 20.0],       # σ² = 0.25
    [22.3, 22.4, 22.7, 22.5, 22.0]        # σ² = 0.75
]

genetico_timespan_data2 = [
    [17.6] * 5,  # σ² = 0.25
    [19.6] * 5   # σ² = 0.75
]

milp_timespan_data2 = [
    [21.0] * 5,  # σ² = 0.25
    [22.7] * 5   # σ² = 0.75
]

genetico_smc_timespan_data = [
    [17.0] * 5,  # σ² = 0.25
    [18.7] * 5   # σ² = 0.75
]

# Gráfico
fig, axs = plt.subplots(1, 1, figsize=(16, 8))
ax2 = axs.twinx()

# Posiciones de los boxplots
positions_genetico_coste = [1, 15]
positions_milp_coste = [2, 16]
positions_genetico2_coste = [3, 17]
positions_milp2_coste = [4, 18]
positions_genetico_smc_coste = [5, 19]

positions_genetico_timespan = [7, 21]
positions_milp_timespan = [8, 22]
positions_genetico2_timespan = [9, 23]
positions_milp2_timespan = [10, 24]
positions_genetico_smc_timespan = [11, 25]

# Boxplots para Disruption (eje izquierdo)
bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=['']*2, widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=['']*2, widths=0.4, patch_artist=True)
bp2 = axs.boxplot(genetico_coste_data2, positions=positions_genetico2_coste, labels=['']*2, widths=0.4, patch_artist=True)
bp2_milp = axs.boxplot(milp_coste_data2, positions=positions_milp2_coste, labels=['']*2, widths=0.4, patch_artist=True)
bpsmc = axs.boxplot(genetico_smc_coste_data, positions=positions_genetico_smc_coste, labels=['']*2, widths=0.4, patch_artist=True)

axs.set_ylabel('Disruption(#events)', fontsize=20, color='green')
axs.set_ylim([14, 37])  # Nuevo rango para Disruption
axs.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

for bp in [bp1, bp1_milp, bp2, bp2_milp, bpsmc]:
    for box in bp['boxes']:
        box.set(color='green', facecolor='lightgreen')

# Boxplots para Timespan (eje derecho)
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_genetico2 = ax2.boxplot(genetico_timespan_data2, positions=positions_genetico2_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_milp2 = ax2.boxplot(milp_timespan_data2, positions=positions_milp2_timespan, labels=['']*2, widths=0.4, patch_artist=True)
bp2_genetico_smc = ax2.boxplot(genetico_smc_timespan_data, positions=positions_genetico_smc_timespan, labels=['']*2, widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:pink')
ax2.set_ylim([12, 24])  # Nuevo rango para Timespan

for bp in [bp2_genetico, bp2_milp, bp2_genetico2, bp2_milp2, bp2_genetico_smc]:
    for box in bp['boxes']:
        box.set(color='deeppink', facecolor='pink')

# Líneas horizontales (Disruption)
for value in range(15, 37, 3):
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.5)

# Sombreado vertical
axs.axvspan(6, 13, color='lightgray', alpha=0.3)
axs.axvspan(20, 26, color='lightgray', alpha=0.3)

# Anotaciones
for i, sigma_label in zip([3, 18], ['σ² = 0.25', 'σ² = 0.75']):
    ax2.text(i + 2.5, 11.2, sigma_label, ha='center', va='center', fontsize=16, color='black')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1, 13, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 2, 13, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 3, 13, 'GA', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 4, 13, 'MILP', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 5.2, 13, 'GSMCA', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1.5, 12.5, 'SIM', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 4, 12.5, 'MC', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 14]:
    ax2.text(i + 3, 11.6, 'Disruption', ha='center', va='center', fontsize=12, color='green')
    ax2.text(i + 9, 11.6, 'Timespan', ha='center', va='center', fontsize=12, color='deeppink')

plt.suptitle('#patients:80 #robots:8 s.p = 0.65', fontsize=20, y=0.92)

axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)
axs.set_xlim([0, 26])

# Guardar y mostrar
plt.savefig('Grafica_RQ14_RoboMAX80_p65.pdf', format='pdf')
plt.show()
# Out:
# <ipython-input-20-04ecba0eade0>:74: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = axs.boxplot(genetico_coste_data, positions=positions_genetico_coste, labels=['']*2, widths=0.4, patch_artist=True)
# <ipython-input-20-04ecba0eade0>:75: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1_milp = axs.boxplot(milp_coste_data, positions=positions_milp_coste, labels=['']*2, widths=0.4, patch_artist=True)
# <ipython-input-20-04ecba0eade0>:76: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp2 = axs.boxplot(genetico_coste_data2, positions=positions_genetico2_coste, labels=['']*2, widths=0.4, patch_artist=True)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

genetico_water_data = [
    [13.7, 13.5, 13.9, 13.8, 13.4],  # σ² = 0.25
    [14.4, 14.2, 14.3, 14.5, 14.1]   # σ² = 0.75
]

milp_water_data = [
    [14.7, 14.5, 14.8, 15.0, 14.6],  # σ² = 0.25
    [15.5, 15.3, 15.6, 15.8, 15.2]   # σ² = 0.75
]

# === Constantes ===
genetico_water_data2 = [
    [13.9] * 5,  # σ² = 0.25
    [14.4] * 5   # σ² = 0.75
]

milp_water_data2 = [
    [14.7] * 5,  # σ² = 0.25
    [15.3] * 5   # σ² = 0.75
]

genetico_smc_water_data = [
    [13.3] * 5,  # σ² = 0.25
    [13.7] * 5   # σ² = 0.75
]

# === Tiempo ===
genetico_timespan_data = [
    [20.1, 19.8, 20.2, 20.4, 19.9],
    [21.3, 21.0, 21.4, 21.6, 20.8]
]

milp_timespan_data = [
    [22.1, 21.8, 22.0, 22.4, 21.6],
    [23.3, 23.0, 23.5, 23.1, 23.2]
]

# === Constantes ===
genetico_timespan_data2 = [
    [19.5] * 5,
    [20.3] * 5
]

milp_timespan_data2 = [
    [21.8] * 5,
    [23.0] * 5
]

genetico_smc_timespan_data = [
    [18.9] * 5,
    [19.7] * 5
]

# === COLORES PERSONALIZADOS ===
color_water = '#b39ddb'
color_water_fill = '#d1c4e9'
color_time = '#388e3c'
color_time_fill = '#a5d6a7'

# === GRÁFICO ===
fig, axs = plt.subplots(1, 1, figsize=(16, 8))
ax2 = axs.twinx()

# Posiciones para los boxplots
positions_genetico_water = [1, 15]
positions_milp_water = [2, 16]
positions_genetico2_water = [3, 17]
positions_milp2_water = [4, 18]
positions_smc_water = [5, 19]

positions_genetico_time = [7, 21]
positions_milp_time = [8, 22]
positions_genetico2_time = [9, 23]
positions_milp2_time = [10, 24]
positions_smc_time = [11, 25]

# === BOXES: WATER USE ===
bp1 = axs.boxplot(genetico_water_data, positions=positions_genetico_water, widths=0.4, patch_artist=True)
bp1_milp = axs.boxplot(milp_water_data, positions=positions_milp_water, widths=0.4, patch_artist=True)
bp2 = axs.boxplot(genetico_water_data2, positions=positions_genetico2_water, widths=0.4, patch_artist=True)
bp2_milp = axs.boxplot(milp_water_data2, positions=positions_milp2_water, widths=0.4, patch_artist=True)
bpsmc = axs.boxplot(genetico_smc_water_data, positions=positions_smc_water, widths=0.4, patch_artist=True)

axs.set_ylabel('Water use (m³)', fontsize=20, color=color_water)
axs.set_ylim([12, 16])
axs.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

for bp in [bp1, bp1_milp, bp2, bp2_milp, bpsmc]:
    for box in bp['boxes']:
        box.set(color=color_water, facecolor=color_water_fill)

# === BOXES: TIMESPAN ===
bp2_genetico = ax2.boxplot(genetico_timespan_data, positions=positions_genetico_time, widths=0.4, patch_artist=True)
bp2_milp = ax2.boxplot(milp_timespan_data, positions=positions_milp_time, widths=0.4, patch_artist=True)
bp2_genetico2 = ax2.boxplot(genetico_timespan_data2, positions=positions_genetico2_time, widths=0.4, patch_artist=True)
bp2_milp2 = ax2.boxplot(milp_timespan_data2, positions=positions_milp2_time, widths=0.4, patch_artist=True)
bp2_smc = ax2.boxplot(genetico_smc_timespan_data, positions=positions_smc_time, widths=0.4, patch_artist=True)

ax2.set_ylabel('Timespan (h)', fontsize=20, color=color_time)
ax2.set_ylim([16, 24])

for bp in [bp2_genetico, bp2_milp, bp2_genetico2, bp2_milp2, bp2_smc]:
    for box in bp['boxes']:
        box.set(color=color_time, facecolor=color_time_fill)

# === LÍNEAS DE REFERENCIA PARA AGUA ===
for value in [12.0, 13.0, 14.0, 15.0]:
    axs.axhline(y=value, color='gray', linestyle='--', linewidth=0.8)

# === SOMBREADO VERTICAL PARA TIMESPAN ===
axs.axvspan(6, 13, color='lightgray', alpha=0.3)
axs.axvspan(20, 26, color='lightgray', alpha=0.3)

# === ANOTACIONES ===
for i, sigma_label in zip([3, 18], ['σ² = 0.25', 'σ² = 0.75']):
    ax2.text(i + 2.5, 15.4, sigma_label, ha='center', va='center', fontsize=16, color='black')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1, 16.6, 'GA', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 2, 16.6, 'MILP', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 3, 16.6, 'GA', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 4, 16.6, 'MILP', ha='center', va='center', fontsize=12, color='brown')
    ax2.text(i + 5.2, 16.6, 'GSMCA', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 6, 14, 20]:
    ax2.text(i + 1.5, 16.2, 'SIM', ha='center', va='center', fontsize=12, color='black')
    ax2.text(i + 4, 16.2, 'MC', ha='center', va='center', fontsize=12, color='brown')

for i in [0, 14]:
    ax2.text(i + 3, 15.8, 'Water use', ha='center', va='center', fontsize=12, color=color_water)
    ax2.text(i + 9, 15.8, 'Timespan', ha='center', va='center', fontsize=12, color=color_time)

# === TÍTULO Y AXIS ===
plt.suptitle('#crops:80 #robots:8 s.p = 0.65', fontsize=20, y=0.92)
axs.tick_params(axis='both', labelsize=12)
ax2.tick_params(axis='both', labelsize=12)
axs.set_xlim([0, 26])

# === GUARDAR Y MOSTRAR ===
plt.savefig('Grafica_RQ14_Agricultura80_p65.pdf', format='pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Datos GRAFICA 1
algoritmo_genetico_coste = [82, 84, 85, 86, 88]
algoritmo_genetico_timespan = [15.5, 16.0, 16.2, 16.4, 16.7]

algoritmo_genetico_coste_md = [85] * 10
algoritmo_genetico_timespan_md = [15.87] * 10

milp_coste = [81] * 10  # Repetir 10 veces el valor 1450
milp_timespan = [15.47] * 10  # Repetir 10 veces el valor 1450

milp_coste_md = [82] * 10  # Repetir 10 veces el valor 1450
milp_timespan_md = [15.67] * 10  # Repetir 10 veces el valor 1450

gsmca_coste = [84] * 10  # Repetir 10 veces el valor 1450
gsmca_timespan = [15.87] * 10  # Repetir 10 veces el valor 1450

# Datos GRAFICA 2
algoritmo_genetico_coste2 = [160,170,180,190,168]
algoritmo_genetico_timespan2 = [16.8,17.0,17.4,17.6,17.7]

milp_coste2 = [160] * 10  # Repetir 10 veces el valor 1450
milp_timespan2 = [16.80] * 10  # Repetir 10 veces el valor 1450

algoritmo_genetico_coste_md2 = [164] * 10
algoritmo_genetico_timespan_md2 = [17.5] * 10

milp_coste_md2 = [161] * 10  # Repetir 10 veces el valor 1450
milp_timespan_md2 = [17] * 10  # Repetir 10 veces el valor 1450

gsmca_coste2 = [162] * 10  # Repetir 10 veces el valor 1450
gsmca_timespan2 = [17.32] * 10  # Repetir 10 veces el valor 1450

# Datos GRAFICA 3
algoritmo_genetico_coste3 = [450,460,436,465,430]
algoritmo_genetico_timespan3 = [19.3,19.0,19.4,19.6,19.5]

milp_coste3 = [426] * 10  # Repetir 10 veces el valor 1450
milp_timespan3 = [18.9] * 10  # Repetir 10 veces el valor 1450

algoritmo_genetico_coste_md3 = [452] * 10
algoritmo_genetico_timespan_md3 = [19.5] * 10

milp_coste_md3 = [430] * 10  # Repetir 10 veces el valor 1450
milp_timespan_md3 = [19] * 10  # Repetir 10 veces el valor 1450

gsmca_coste3 = [442] * 10  # Repetir 10 veces el valor 1450
gsmca_timespan3 = [19.2] * 10  # Repetir 10 veces el valor 1450





# Configuración del gráfico
fig, axs = plt.subplots(1, 3, figsize=(24, 6))
plt.subplots_adjust(wspace=0.5)  # Ajusta el espacio entre las subgráficas

for i, ax in enumerate(axs):

    # Crear un segundo eje y para timespan en el lado derecho
    ax2 = ax.twinx()

    #GRAFICA 1
    if i == 0:
        # Establece límites específicos para el eje y izquierdo en cada gráfica
        ax.set_ylim([75, 90])

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste, milp_coste, algoritmo_genetico_coste_md, milp_coste_md, gsmca_coste], positions=[1, 1.5 ,2, 2.5, 3], labels=[' ', ' ',' ', ' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan, milp_timespan,algoritmo_genetico_timespan_md, milp_timespan_md, gsmca_timespan], positions=[4.5, 5, 5.5, 6, 6.5], labels=[' ', ' ',' ', ' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#EVs:20 #chargers:2', fontsize=20)

    #GRAFICA 2
    elif i == 1:
        ax.set_ylim([150, 200])  # Ajusta según tus necesidades

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste2, milp_coste2, algoritmo_genetico_coste_md2, milp_coste_md2, gsmca_coste2], positions=[1, 1.5 ,2, 2.5, 3], labels=[' ', ' ',' ', ' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan2, milp_timespan2,algoritmo_genetico_timespan_md2, milp_timespan_md2, gsmca_timespan2], positions=[4.5, 5, 5.5, 6, 6.5], labels=[' ', ' ',' ', ' ', ' '], widths=0.4, patch_artist=True)

        # Añadir título superior
        ax.set_title('#EVs:40 #chargers:4', fontsize=20)

    #GRAFICA 3
    elif i == 2:
        ax.set_ylim([400,470])  # Ajusta según tus necesidades

        # Boxplots para el coste en el eje izquierdo
        bp1 = ax.boxplot([algoritmo_genetico_coste3, milp_coste3, algoritmo_genetico_coste_md3, milp_coste_md3, gsmca_coste3], positions=[1, 1.5 ,2, 2.5, 3], labels=[' ', ' ',' ', ' ', ' '], widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan3, milp_timespan3,algoritmo_genetico_timespan_md3, milp_timespan_md3, gsmca_timespan3], positions=[4.5, 5, 5.5, 6, 6.5], labels=[' ', ' ',' ', ' ', ' '], widths=0.4, patch_artist=True)


        # Añadir título superior
        ax.set_title('#EVs:80 #chargers:8', fontsize=20)



    ax.set_ylabel('Cost(€)', fontsize=20, color='tab:blue')

    # Colorea los boxplots de coste
    colors_coste = ['lightblue', 'lightblue']
    for box, color in zip(bp1['boxes'], colors_coste):
        box.set(color='blue', facecolor=color)

    # Ajusta el formato de los ticks en el eje izquierdo
    ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}'.format))

    # Oculta las etiquetas en el eje x
    ax.tick_params(axis='x', which='both', bottom=False)

    ax2.text(1, 15, 'GA', ha='center', va='center', fontsize=10, color='black')
    ax2.text(1.5, 15, 'MILP', ha='center', va='center', fontsize=10, color='black')
    ax2.text(2, 15, 'GA', ha='center', va='center', fontsize=10, color='brown')
    ax2.text(2.45, 15, 'MILP', ha='center', va='center', fontsize=10, color='brown')
    ax2.text(3.1, 15, 'GSMCA', ha='center', va='center', fontsize=10, color='brown')

    ax2.text(4.5, 15, 'GA', ha='center', va='center', fontsize=10, color='black')
    ax2.text(5, 15, 'MILP', ha='center', va='center', fontsize=10, color='black')
    ax2.text(5.5, 15, 'GA', ha='center', va='center', fontsize=10, color='brown')
    ax2.text(5.95, 15, 'MILP', ha='center', va='center', fontsize=10, color='brown')
    ax2.text(6.6, 15, 'GSMCA', ha='center', va='center', fontsize=10, color='brown')

    ax2.text(1.3, 14.7, 'SIM', ha='center', va='center', fontsize=10, color='black')
    ax2.text(2.5, 14.7, 'MC', ha='center', va='center', fontsize=10, color='brown')
    ax2.text(4.8,14.7, 'SIM', ha='center', va='center', fontsize=10, color='black')
    ax2.text(6,14.7, 'MC', ha='center', va='center', fontsize=10, color='brown')

    ax2.set_ylabel('Timespan(h)', fontsize=20, color='tab:red')
    ax2.set_ylim([14.5, 20])  # Ajusta el rango según tus datos

    ax2.text(2, 14, 'Cost', ha='center', va='center', fontsize=20, color='blue')
    ax2.text(5.7, 14, 'Timespan', ha='center', va='center', fontsize=20, color='red')

    # Colorea los boxplots de timespan
    colors_timespan = ['lightsalmon', 'lightsalmon']
    for box, color in zip(bp2['boxes'], colors_timespan):
        box.set(color='red', facecolor=color)



    # Ajusta el tamaño de las etiquetas de los ejes
    ax.tick_params(axis='both', labelsize=12)
    ax2.tick_params(axis='both', labelsize=12)


plt.savefig('Grafica_RQ11_Vehiculos.pdf', format='pdf')
plt.show()
# Out:
# <ipython-input-8-376a532f57b8>:71: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = ax.boxplot([algoritmo_genetico_coste, milp_coste, algoritmo_genetico_coste_md, milp_coste_md, gsmca_coste], positions=[1, 1.5 ,2, 2.5, 3], labels=[' ', ' ',' ', ' ', ' '], widths=0.4, patch_artist=True)
# <ipython-input-8-376a532f57b8>:72: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp2 = ax2.boxplot([algoritmo_genetico_timespan, milp_timespan,algoritmo_genetico_timespan_md, milp_timespan_md, gsmca_timespan], positions=[4.5, 5, 5.5, 6, 6.5], labels=[' ', ' ',' ', ' ', ' '], widths=0.4, patch_artist=True)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# === Datos ADAPTADOS A NUEVA ESCALA DE DISRUPTION ===

# GRAFICA 1
algoritmo_genetico_coste = [6, 7, 8, 6, 7]
algoritmo_genetico_timespan = [15.7, 16.0, 16.2, 16.4, 16.4]
algoritmo_genetico_coste_md = [7] * 10
algoritmo_genetico_timespan_md = [15.74] * 10
milp_coste = [5] * 10
milp_timespan = [15.32] * 10
milp_coste_md = [6] * 10
milp_timespan_md = [15.43] * 10
gsmca_coste = [6.8] * 10
gsmca_timespan = [15.55] * 10

# GRAFICA 2
algoritmo_genetico_coste2 = [10, 12, 13, 14, 11]
algoritmo_genetico_timespan2 = [17.0, 17.2, 17.4, 17.6, 17.8]
milp_coste2 = [9] * 10
milp_timespan2 = [16.80] * 10
algoritmo_genetico_coste_md2 = [11] * 10
algoritmo_genetico_timespan_md2 = [17.4] * 10
milp_coste_md2 = [10] * 10
milp_timespan_md2 = [17.1] * 10
gsmca_coste2 = [10.5] * 10
gsmca_timespan2 = [17.27] * 10

# GRAFICA 3
algoritmo_genetico_coste3 = [15, 16, 17, 16, 18]
algoritmo_genetico_timespan3 = [18.8, 19.0, 19.4, 19.6, 19.8]
milp_coste3 = [14.8] * 10
milp_timespan3 = [18.6] * 10
algoritmo_genetico_coste_md3 = [16] * 10
algoritmo_genetico_timespan_md3 = [19.2] * 10
milp_coste_md3 = [15] * 10
milp_timespan_md3 = [18.6] * 10
gsmca_coste3 = [15.6] * 10
gsmca_timespan3 = [18.9] * 10

# === Configuración del gráfico ===
fig, axs = plt.subplots(1, 3, figsize=(24, 6))
plt.subplots_adjust(wspace=0.5)

for i, ax in enumerate(axs):
    ax2 = ax.twinx()

    if i == 0:
        ax.set_ylim([0, 10])
        bp1 = ax.boxplot([algoritmo_genetico_coste, milp_coste, algoritmo_genetico_coste_md, milp_coste_md, gsmca_coste],
                         positions=[1, 1.5, 2, 2.5, 3], labels=[' ', ' ', ' ', ' ', ' '],
                         widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan, milp_timespan, algoritmo_genetico_timespan_md, milp_timespan_md, gsmca_timespan],
                          positions=[4.5, 5, 5.5, 6, 6.5], labels=[' ', ' ', ' ', ' ', ' '],
                          widths=0.4, patch_artist=True)
        ax.set_title('#patients:20 #robots:2', fontsize=20)

    elif i == 1:
        ax.set_ylim([5, 15])
        bp1 = ax.boxplot([algoritmo_genetico_coste2, milp_coste2, algoritmo_genetico_coste_md2, milp_coste_md2, gsmca_coste2],
                         positions=[1, 1.5, 2, 2.5, 3], labels=[' ', ' ', ' ', ' ', ' '],
                         widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan2, milp_timespan2, algoritmo_genetico_timespan_md2, milp_timespan_md2, gsmca_timespan2],
                          positions=[4.5, 5, 5.5, 6, 6.5], labels=[' ', ' ', ' ', ' ', ' '],
                          widths=0.4, patch_artist=True)
        ax.set_title('#patients:40 #robots:4', fontsize=20)

    elif i == 2:
        ax.set_ylim([10, 20])
        bp1 = ax.boxplot([algoritmo_genetico_coste3, milp_coste3, algoritmo_genetico_coste_md3, milp_coste_md3, gsmca_coste3],
                         positions=[1, 1.5, 2, 2.5, 3], labels=[' ', ' ', ' ', ' ', ' '],
                         widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([algoritmo_genetico_timespan3, milp_timespan3, algoritmo_genetico_timespan_md3, milp_timespan_md3, gsmca_timespan3],
                          positions=[4.5, 5, 5.5, 6, 6.5], labels=[' ', ' ', ' ', ' ', ' '],
                          widths=0.4, patch_artist=True)
        ax.set_title('#patients:80 #robots:8', fontsize=20)

    ax.set_ylabel('Disruption(#events)', fontsize=20, color='green')

    for box in bp1['boxes']:
        box.set(color='green', facecolor='lightgreen')

    ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}'.format))
    ax.tick_params(axis='x', which='both', bottom=False)

    ax2.set_ylabel('Timespan(h)', fontsize=20, color=(0.91, 0.41, 0.71))
    ax2.set_ylim([14.5, 20])

    for box in bp2['boxes']:
        box.set(color=(0.91, 0.41, 0.71), facecolor='lightpink')

    etiquetas_coste = ['GA', 'MILP', 'GA', 'MILP', 'GSMCA']
    etiquetas_tipo = ['SIM', 'SIM', 'MC', 'MC', 'MC']

    for idx, x in enumerate([0.8, 1.3, 1.8, 2.3, 2.9]):
        ax2.text(x, 15, etiquetas_coste[idx], ha='center', va='center', fontsize=10, color='black' if idx < 2 else 'brown')
        ax2.text(x, 14.7, etiquetas_tipo[idx], ha='center', va='center', fontsize=10, color='black' if idx < 2 else 'brown')

    for idx, x in enumerate([4.4, 4.9, 5.4, 5.9, 6.5]):
        ax2.text(x, 15, etiquetas_coste[idx], ha='center', va='center', fontsize=10, color='black' if idx < 2 else 'brown')
        ax2.text(x, 14.7, etiquetas_tipo[idx], ha='center', va='center', fontsize=10, color='black' if idx < 2 else 'brown')

    ax2.text(2, 14, 'Disruption', ha='center', va='center', fontsize=20, color='green')
    ax2.text(5.7, 14, 'Timespan', ha='center', va='center', fontsize=20, color=(0.91, 0.41, 0.71))

    ax.tick_params(axis='both', labelsize=12)
    ax2.tick_params(axis='both', labelsize=12)

plt.savefig('Grafica_RQ11_Robomax.pdf', format='pdf')
plt.show()
# Out:
# <ipython-input-9-2c488363cce2>:51: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = ax.boxplot([algoritmo_genetico_coste, milp_coste, algoritmo_genetico_coste_md, milp_coste_md, gsmca_coste],
# <ipython-input-9-2c488363cce2>:54: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp2 = ax2.boxplot([algoritmo_genetico_timespan, milp_timespan, algoritmo_genetico_timespan_md, milp_timespan_md, gsmca_timespan],
# <ipython-input-9-2c488363cce2>:61: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = ax.boxplot([algoritmo_genetico_coste2, milp_coste2, algoritmo_genetico_coste_md2, milp_coste_md2, gsmca_coste2],
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# === DATOS AJUSTADOS PARA CADA CASO ===

# GRAFICA 1 - #crops:20 #robots:2
ga_water1 = [3.3, 3.2, 3.1, 3.4, 3.5]
ga_time1 = [15.7, 16.2, 15.8, 16.3, 15.9]
ga_water_md1 = [3.2] * 10
ga_time_md1 = [16] * 10
milp_water1 = [3.0] * 10
milp_time1 = [15.3] * 10
milp_water_md1 = [3.1] * 10
milp_time_md1 = [15.6] * 10
gsmca_water1 = [3.2] * 10
gsmca_time1 = [15.7] * 10

# GRAFICA 2 - #crops:40 #robots:4
ga_water2 = [6.7, 7.0, 7.2, 6.8, 7.1]
ga_time2 = [17.1, 17.3, 17.5, 17.4, 17.7]
ga_water_md2 = [7] * 10
ga_time_md2 = [17.5] * 10
milp_water2 = [6.5] * 10
milp_time2 = [17.0] * 10
milp_water_md2 = [6.7] * 10
milp_time_md2 = [17.3] * 10
gsmca_water2 = [6.8] * 10
gsmca_time2 = [17.4] * 10

# GRAFICA 3 - #crops:80 #robots:8
ga_water3 = [13.2, 14.0, 13.5, 14.2, 14.5]
ga_time3 = [18.2, 18.4, 18.6, 18.8, 18.9]
ga_water_md3 = [13.6] * 10
ga_time_md3 = [18.6] * 10
milp_water3 = [13] * 10
milp_time3 = [18.1] * 10
milp_water_md3 = [13.2] * 10
milp_time_md3 = [18.3] * 10
gsmca_water3 = [13.5] * 10
gsmca_time3 = [18.4] * 10

# === COLORES PERSONALIZADOS ===
color_water = '#9467bd'     # Lila
color_water_fill = '#d1c4e9'
color_time = '#388e3c'      # Verde oscuro para texto
color_time_fill = '#a5d6a7' # Verde claro

# === GRÁFICO ===
fig, axs = plt.subplots(1, 3, figsize=(24, 6))
plt.subplots_adjust(wspace=0.5)

for i, ax in enumerate(axs):
    ax2 = ax.twinx()

    if i == 0:
        ax.set_ylim([2.5, 4])
        bp1 = ax.boxplot([ga_water1, milp_water1, ga_water_md1, milp_water_md1, gsmca_water1],
                         positions=[1, 1.5, 2, 2.5, 3], labels=[' '] * 5, widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([ga_time1, milp_time1, ga_time_md1, milp_time_md1, gsmca_time1],
                          positions=[4.5, 5, 5.5, 6, 6.5], labels=[' '] * 5, widths=0.4, patch_artist=True)
        ax.set_title('#crops:20 #robots:2', fontsize=20)

    elif i == 1:
        ax.set_ylim([6, 8])
        bp1 = ax.boxplot([ga_water2, milp_water2, ga_water_md2, milp_water_md2, gsmca_water2],
                         positions=[1, 1.5, 2, 2.5, 3], labels=[' '] * 5, widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([ga_time2, milp_time2, ga_time_md2, milp_time_md2, gsmca_time2],
                          positions=[4.5, 5, 5.5, 6, 6.5], labels=[' '] * 5, widths=0.4, patch_artist=True)
        ax.set_title('#crops:40 #robots:4', fontsize=20)

    elif i == 2:
        ax.set_ylim([12, 16])
        bp1 = ax.boxplot([ga_water3, milp_water3, ga_water_md3, milp_water_md3, gsmca_water3],
                         positions=[1, 1.5, 2, 2.5, 3], labels=[' '] * 5, widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([ga_time3, milp_time3, ga_time_md3, milp_time_md3, gsmca_time3],
                          positions=[4.5, 5, 5.5, 6, 6.5], labels=[' '] * 5, widths=0.4, patch_artist=True)
        ax.set_title('#crops:80 #robots:8', fontsize=20)

    # EJE Y PRIMARIO: USO DE AGUA
    ax.set_ylabel('Water use (m³)', fontsize=20, color=color_water)
    for box in bp1['boxes']:
        box.set(color=color_water, facecolor=color_water_fill)

    # EJE Y SECUNDARIO: TIEMPO
    ax2.set_ylabel('Timespan (h)', fontsize=20, color=color_time)
    ax2.set_ylim([14.5, 20])
    for box in bp2['boxes']:
        box.set(color=color_time, facecolor=color_time_fill)

    # FORMATO DE ETIQUETAS
    etiquetas_modelo = ['GA', 'MILP', 'GA', 'MILP', 'GSMCA']
    etiquetas_tipo = ['SIM', 'SIM', 'MC', 'MC', 'MC']

    for idx, x in enumerate([0.8, 1.3, 1.8, 2.3, 2.9]):
        ax2.text(x, 15, etiquetas_modelo[idx], ha='center', va='center', fontsize=10,
                 color='black' if idx < 2 else 'brown')
        ax2.text(x, 14.7, etiquetas_tipo[idx], ha='center', va='center', fontsize=10,
                 color='black' if idx < 2 else 'brown')

    for idx, x in enumerate([4.4, 4.9, 5.4, 5.9, 6.5]):
        ax2.text(x, 15, etiquetas_modelo[idx], ha='center', va='center', fontsize=10,
                 color='black' if idx < 2 else 'brown')
        ax2.text(x, 14.7, etiquetas_tipo[idx], ha='center', va='center', fontsize=10,
                 color='black' if idx < 2 else 'brown')

    ax2.text(2, 14.1, 'Water use', ha='center', va='center', fontsize=20, color=color_water)
    ax2.text(5.7, 14.1, 'Timespan', ha='center', va='center', fontsize=20, color=color_time)

    ax.tick_params(axis='both', labelsize=12)
    ax2.tick_params(axis='both', labelsize=12)
    ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.1f}'.format))
    ax.tick_params(axis='x', which='both', bottom=False)

plt.savefig('Grafica_RQ11_Agriculrura.pdf', format='pdf')
plt.show()
# Out:
# <ipython-input-10-b5c4d3b881f2>:57: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = ax.boxplot([ga_water1, milp_water1, ga_water_md1, milp_water_md1, gsmca_water1],
# <ipython-input-10-b5c4d3b881f2>:59: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp2 = ax2.boxplot([ga_time1, milp_time1, ga_time_md1, milp_time_md1, gsmca_time1],
# <ipython-input-10-b5c4d3b881f2>:65: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = ax.boxplot([ga_water2, milp_water2, ga_water_md2, milp_water_md2, gsmca_water2],
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# === DATOS SIMULADOS PARA CADA CASO ===

# GRAFICA 1 - #crops:20 #robots:2
ga_water1 = [120, 130, 125, 128, 132]
ga_time1 = [15.1, 15.0, 15.3, 15.2, 15.4]
ga_water_md1 = [128] * 10
ga_time_md1 = [15.25] * 10
milp_water1 = [115] * 10
milp_time1 = [15.0] * 10
milp_water_md1 = [120] * 10
milp_time_md1 = [15.1] * 10
gsmca_water1 = [125] * 10
gsmca_time1 = [15.3] * 10

# GRAFICA 2 - #crops:40 #robots:4
ga_water2 = [180, 185, 190, 182, 188]
ga_time2 = [17.2, 17.3, 17.5, 17.4, 17.6]
ga_water_md2 = [185] * 10
ga_time_md2 = [17.4] * 10
milp_water2 = [170] * 10
milp_time2 = [17.1] * 10
milp_water_md2 = [175] * 10
milp_time_md2 = [17.2] * 10
gsmca_water2 = [180] * 10
gsmca_time2 = [17.3] * 10

# GRAFICA 3 - #crops:80 #robots:8
ga_water3 = [250, 260, 255, 265, 270]
ga_time3 = [18.5, 18.7, 18.6, 18.8, 18.9]
ga_water_md3 = [260] * 10
ga_time_md3 = [18.7] * 10
milp_water3 = [240] * 10
milp_time3 = [18.5] * 10
milp_water_md3 = [250] * 10
milp_time_md3 = [18.6] * 10
gsmca_water3 = [258] * 10
gsmca_time3 = [18.8] * 10

# === GRÁFICO ===
fig, axs = plt.subplots(1, 3, figsize=(24, 6))
plt.subplots_adjust(wspace=0.5)

for i, ax in enumerate(axs):
    ax2 = ax.twinx()

    if i == 0:
        ax.set_ylim([100, 140])
        bp1 = ax.boxplot([ga_water1, milp_water1, ga_water_md1, milp_water_md1, gsmca_water1],
                         positions=[1, 1.5, 2, 2.5, 3], labels=[' '] * 5, widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([ga_time1, milp_time1, ga_time_md1, milp_time_md1, gsmca_time1],
                          positions=[4.5, 5, 5.5, 6, 6.5], labels=[' '] * 5, widths=0.4, patch_artist=True)
        ax.set_title('#crops:20 #robots:2', fontsize=20)

    elif i == 1:
        ax.set_ylim([160, 200])
        bp1 = ax.boxplot([ga_water2, milp_water2, ga_water_md2, milp_water_md2, gsmca_water2],
                         positions=[1, 1.5, 2, 2.5, 3], labels=[' '] * 5, widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([ga_time2, milp_time2, ga_time_md2, milp_time_md2, gsmca_time2],
                          positions=[4.5, 5, 5.5, 6, 6.5], labels=[' '] * 5, widths=0.4, patch_artist=True)
        ax.set_title('#crops:40 #robots:4', fontsize=20)

    elif i == 2:
        ax.set_ylim([230, 280])
        bp1 = ax.boxplot([ga_water3, milp_water3, ga_water_md3, milp_water_md3, gsmca_water3],
                         positions=[1, 1.5, 2, 2.5, 3], labels=[' '] * 5, widths=0.4, patch_artist=True)
        bp2 = ax2.boxplot([ga_time3, milp_time3, ga_time_md3, milp_time_md3, gsmca_time3],
                          positions=[4.5, 5, 5.5, 6, 6.5], labels=[' '] * 5, widths=0.4, patch_artist=True)
        ax.set_title('#crops:80 #robots:8', fontsize=20)

    # EJE Y PRIMARIO: USO DE AGUA
    ax.set_ylabel('Water use (m³)', fontsize=20, color='#1f77b4')
    for box in bp1['boxes']:
        box.set(color='#1f77b4', facecolor='#aec7e8')

    # EJE Y SECUNDARIO: TIEMPO
    ax2.set_ylabel('Timespan (h)', fontsize=20, color='#9467bd')
    ax2.set_ylim([14.5, 20])
    for box in bp2['boxes']:
        box.set(color='#9467bd', facecolor='#d5b0e3')

    # FORMATO DE ETIQUETAS
    etiquetas_modelo = ['GA', 'MILP', 'GA', 'MILP', 'GSMCA']
    etiquetas_tipo = ['SIM', 'SIM', 'MC', 'MC', 'MC']

    for idx, x in enumerate([1, 1.5, 2, 2.5, 3]):
        ax2.text(x, 14.6, etiquetas_modelo[idx], ha='center', va='center', fontsize=10, color='black' if idx < 2 else 'brown')
        ax2.text(x, 14.4, etiquetas_tipo[idx], ha='center', va='center', fontsize=10, color='black' if idx < 2 else 'brown')

    for idx, x in enumerate([4.5, 5, 5.5, 6, 6.5]):
        ax2.text(x, 14.6, etiquetas_modelo[idx], ha='center', va='center', fontsize=10, color='black' if idx < 2 else 'brown')
        ax2.text(x, 14.4, etiquetas_tipo[idx], ha='center', va='center', fontsize=10, color='black' if idx < 2 else 'brown')

    ax2.text(2, 14.1, 'Water use', ha='center', va='center', fontsize=20, color='#1f77b4')
    ax2.text(5.7, 14.1, 'Timespan', ha='center', va='center', fontsize=20, color='#9467bd')

    ax.tick_params(axis='both', labelsize=12)
    ax2.tick_params(axis='both', labelsize=12)
    ax.yaxis.set_major_formatter(plt.FuncFormatter('{:.0f}'.format))
    ax.tick_params(axis='x', which='both', bottom=False)

plt.savefig('Grafica_Agricultura_CropsRobots_Final.pdf', format='pdf')
plt.show()
# Out:
# <ipython-input-34-25a2122bf362>:51: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = ax.boxplot([ga_water1, milp_water1, ga_water_md1, milp_water_md1, gsmca_water1],
# <ipython-input-34-25a2122bf362>:53: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp2 = ax2.boxplot([ga_time1, milp_time1, ga_time_md1, milp_time_md1, gsmca_time1],
# <ipython-input-34-25a2122bf362>:59: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp1 = ax.boxplot([ga_water2, milp_water2, ga_water_md2, milp_water_md2, gsmca_water2],
# ...
